# %%
import string
print (string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
mydic = {'artificial_intelligence.txt': {'1940s': 1, '1950s': 2, '1956newell': 1, '1960s': 4, '1970s': 1, '1980s': 8, '1990s': 5, '1997in': 1, '2000s': 1, '2010s': 2, '2015the': 1, '21st': 1, '3d': 1, 'aaai': 2, 'abandoned': 2, 'abilities': 1, 'ability': 11, 'able': 11, 'abnormal': 1, 'abstract': 4, 'academic': 4, 'accelerated': 1, 'accelerating': 1, 'acceptable': 1, 'accepted': 1, 'accepts': 1, 'access': 2, 'accessible': 1, 'accident': 1, 'accidents': 1, 'accomplish': 2, 'accordance': 2, 'according': 6, 'accordingly': 1, 'accounting': 1, 'accumulate': 1, 'accuracy': 5, 'accurate': 2, 'achieve': 7, 'achieved': 1, 'achieving': 3, 'acknowledge': 1, 'acknowledged': 1, 'acknowledging': 1, 'acquire': 1, 'acquired': 1, 'acquiring': 2, 'acquisition': 2, 'acronym': 1, 'across': 3, 'act': 2, 'acting': 3, 'action': 2, 'actionable': 1, 'actions': 11, 'activate': 1, 'activated': 1, 'activation': 3, 'active': 2, 'actor': 1, 'actual': 4, 'actually': 4, 'acyclic': 1, 'ad': 1, 'adam': 1, 'adapt': 1, 'adaptation': 2, 'add': 1, 'adding': 2, 'addition': 3, 'additional': 1, 'address': 1, 'adds': 1, 'adhoc': 1, 'adjust': 3, 'administered': 2, 'adopted': 1, 'adoption': 1, 'ads': 1, 'adsense': 1, 'adult': 2, 'advanced': 5, 'advancement': 1, 'advancements': 1, 'advances': 6, 'advancing': 1, 'advantage': 1, 'adversarial': 1, 'advertisements': 1, 'advertising': 2, 'advocated': 2, 'advocating': 1, 'aeronautical': 1, 'affect': 1, 'affective': 2, 'affects': 3, 'affinity': 1, 'affordable': 1, 'agar': 1, 'age': 3, 'agent': 21, 'agents': 14, 'agi': 4, 'agree': 2, 'agreed': 1, 'ai': 211, 'aibased': 1, 'aicomplete': 1, 'aicpa': 1, 'aim': 2, 'aimed': 1, 'airelated': 1, 'ais': 2, 'aitopics': 1, 'aizenberg': 1, 'alan': 2, 'aldous': 1, 'aleksander': 1, 'alexey': 2, 'algebra': 1, 'algorithm': 16, 'algorithmic': 2, 'algorithms': 27, 'alice': 1, 'aliens': 1, 'alison': 1, 'alleged': 1, 'allen': 2, 'alleviating': 1, 'allow': 6, 'allowing': 1, 'allows': 2, 'almost': 4, 'along': 3, 'alongside': 1, 'alphago': 4, 'alphazero': 1, 'already': 5, 'also': 43, 'altered': 1, 'altering': 1, 'alternative': 1, 'alternatively': 2, 'although': 2, 'always': 1, 'ama': 1, 'amari': 1, 'amas': 2, 'amazon': 1, 'ambiguity': 1, 'ambiguous': 1, 'americans': 1, 'among': 9, 'amount': 3, 'amounts': 4, 'analog': 1, 'analogies': 1, 'analogizers': 1, 'analogy': 1, 'analysis': 6, 'analytical': 1, 'analyticscrunching': 1, 'analyze': 4, 'analyzes': 1, 'andrew': 2, 'androids': 1, 'angeles': 1, 'animal': 2, 'animals': 3, 'ann': 1, 'annealing': 1, 'annual': 1, 'anomalies': 1, 'another':
ively': 1, 'college': 1, 'collision': 2, 'colloquially': 1, 'colony': 1, 'color': 3, 'combat': 1, 'combination': 2, 'combinations': 2, 'combinatorial': 3, 'combine': 2, 'combined': 2, 'combining': 1, 'come': 4, 'comes': 2, 'commander': 2, 'commercial': 1, 'commercially': 1, 'commitment': 1, 'committed': 1, 'common': 6, 'commonly': 1, 'commonsense': 10, 'communicate': 2, 'communications': 1, 'community': 1, 'companies': 6, 'company': 1, 'comparatively': 1, 'compare': 3, 'compared': 3, 'comparing': 2, 'compas': 2, 'compatible': 1, 'compete': 1, 'competed': 1, 'competing': 2, 'competition': 3, 'competitions': 2, 'competitive': 2, 'complementary': 1, 'complete': 5, 'completely': 3, 'completes': 1, 'completion': 1, 'complex': 9, 'complexity': 4, 'compliant': 1, 'complicated': 5, 'component': 2, 'components': 3, 'comprehend': 1, 'comprehensive': 2, 'comprises': 1, 'computation': 4, 'computational': 10, 'computationalism': 4, 'computationally': 2, 'compute': 1, 'computed': 1, 'computer': 30, 'computers': 14, 'computing': 9, 'computing—they': 1, 'conceivable': 1, 'concept': 7, 'conception': 1, 'concepts': 5, 'conceptually': 1, 'concern': 4, 'concerned': 4, 'concerning': 2, 'concerns': 3, 'conclude': 1, 'conclusions': 1, 'concurrent': 2, 'conditional': 1, 'conditionally': 1, 'conditions': 2, 'conference': 1, 'configuration': 1, 'confront': 1, 'congress': 1, 'conjecture': 1, 'conjunction': 1, 'connected': 1, 'connection': 1, 'connectionism': 1, 'connectionist': 1, 'connections': 2, 'conscious': 3, 'consciousness': 7, 'consensus': 1, 'consequences': 3, 'consider': 7, 'considerations': 1, 'considered': 11, 'considering': 2, 'considers': 1, 'consist': 1, 'consistently': 1, 'consists': 2, 'constant': 1, 'constraints': 2, 'construct': 1, 'contact': 1, 'contain': 3, 'containing': 1, 'content': 1, 'contentaltering': 1, 'contentbased': 1, 'context': 2, 'continue': 5, 'continued': 1, 'continuing': 1, 'continuous': 3, 'continuously': 1, 'contradictory': 1, 'contrary': 1, 'contrast': 5, 'contribute': 2, 'contributed': 2, 'contributing': 1, 'control': 7, 'controllers': 2, 'controls': 1, 'controversially': 1, 'convention': 1, 'conventional': 2, 'converge': 1, 'convergent': 1, 'convergently': 1, 'conversation': 1, 'conversational': 1, 'conversationally': 1, 'conversely': 1, 'conveying': 1, 'convinced': 1, 'convolutional': 2, 'cooccurrence': 1, 'cooks': 1, 'cooperation': 1, 'coordinate': 1, 'coordination': 3, 'copy': 1, 'corner': 3, 'corporate': 1, 'corporation': 1, 'corporations': 1, 'correct': 1, 'correctional': 1, 'correctly': 2, 'correlate': 1, 'correlating': 1, 'cost': 1, 'could': 28, 'councilmen': 2, 'count': 1, 'counter': 1, 'counterarguments': 1, 'counterfactual': 1, 'counterintuitively': 1, 'counterpart': 1, 'counters': 1, 'countries': 1, 'counts': 1, 'couple': 1, 'coupled': 1, 'course': 2, 'cover': 2, 'create': 5, 'created': 3, 'creates': 2, 'creating': 7, 'creation': 3, 'creative': 1, 'creatives': 1, 'credit': 1, 'crimes': 1, 'criminals': 1, 'critic': 1, 'critical': 1, 'criticism': 1, 'critics': 3, 'critique': 1, 'crossdomain': 2, 'crucial': 1, 'ct': 1, 'ctc': 1, 'ctctrained': 1, 'culminate': 1, 'culture': 2, 'curb': 1, 'curing': 1, 'current': 8, 'currently': 2, 'currentlyundiscovered': 1, 'curves': 1, 'custombuilt': 1, 'customer': 4, 'customers': 1, 'cut': 1, 'cutting': 1, 'cyberneticist': 2, 'cybernetics': 6, 'cybersecurity': 2, 'cyborgs': 1, 'cyc': 3, 'cycles': 1, 'daimler': 1, 'damage': 1, 'danger': 3, 'dangerous': 6, 'dartmouth': 3, 'darwin': 1, 'data': 30, 'database': 1, 'databases': 1, 'datahungry': 1, 'datamining': 1, 'dataset': 1, 'datasets': 3, 'david': 3, 'day': 2, 'days': 1, 'dead': 2, 'deal': 1, 'dealing': 1, 'debit': 1, 'dec': 1, 'decade': 1, 'decades': 2, 'dechter': 1, 'decide': 4, 'decision': 17, 'decisions': 3, 'decisiontheoretic': 1, 'deconfliction': 1, 'decrease': 1, 'dedicated': 1, 'deduce': 1, 'deduction': 2, 'deductions': 1, 'deemed': 1, 'deep': 20, 'deepdream': 1, 'deeper': 1, 'deepfakes': 2, 'deeply': 1, 'deepmind': 3, 'default': 3, 'defeated': 1, 'defendants': 3, 'defenders': 1, 'defense': 1, 'deference': 1, 'define': 1, 'defined': 1, 'defines': 1, 'definition': 3, 'definitions': 1, 'degree': 3, 'delays': 1, 'delineated': 1, 'delivery': 1, 'demand': 4, 'demonstrate': 1, 'demonstrated': 2, 'demonstration': 1, 'demonstrators': 2, 'denial': 1, 'density': 1, 'denver': 1, 'department': 1, 'depending': 1, 'depends': 3, 'depicting': 1, 'deploy': 1, 'deployment': 1, 'depth': 2, 'der': 1, 'derivative': 1, 'derive': 1, 'descent': 3, 'describe': 3, 'described': 11, 'describes': 3, 'description': 2, 'deserve': 1, 'design': 4, 'designed': 7, 'designer': 1, 'desire': 1, 'desired': 1, 'desktop': 1, 'despite': 1, 'destination': 1, 'detail': 1, 'detailed': 1, 'detect': 1, 'detection': 1, 'determine': 6, 'determined': 1, 'devaluation': 1, 'devalues': 1, 'develop': 3, 'developed': 11, 'developers': 1, 'developing': 3, 'development': 15, 'developmental': 2, 'developments': 2, 'device': 3, 'devices': 2, 'devise': 1, 'devised': 1, 'dexterity': 1, 'diagnosis': 5, 'diamond': 1, 'diamonds': 1, 'dick': 2, 'difference': 1, 'differences': 1, 'different': 14, 'differentiation': 1, 'difficult': 12, 'difficulties': 1, 'difficulty': 5, 'digital': 6, 'digits': 1, 'dilemmas': 1, 'dimension': 2, 'dimensionality': 1, 'direct': 1, 'direction': 1, 'directly': 4, 'director': 1, 'directory': 1, 'disagree': 1, 'disagreement': 1, 'disappoint': 1, 'disappointment': 1, 'disassembled': 1, 'discerning': 1, 'discipline': 2, 'discount': 1, 'discourse': 1, 'discoveries': 1, 'discovering': 1, 'discovery': 4, 'discriminative': 1, 'discussed': 4, 'discussion': 3, 'discussions': 1, 'disease': 1, 'di
higher': 4, 'highest': 2, 'highlevel': 1, 'highlighting': 1, 'highly': 2, 'highperformance': 1, 'highprofile': 3, 'highrisk': 3, 'highscoring': 1, 'highway': 1, 'hilary': 1, 'hill': 1, 'hinton': 1, 'historical': 1, 'historically': 1, 'history': 3, 'hitting': 1, 'hmm': 3, 'hoc': 1, 'hochreiter': 1, 'holograms': 1, 'hoped': 1, 'hopfield': 1, 'hopkins': 1, 'horrifying': 1, 'horses': 2, 'hospitality': 2, 'host': 1, 'hotel': 1, 'however': 11, 'https': 1, 'hubert': 1, 'huge': 2, 'human': 74, 'humanity': 7, 'humanitys—one': 1, 'humankind': 1, 'humanlevel': 1, 'humanlike': 1, 'humanmachine': 1, 'humans': 32, 'humanwritten': 1, 'human–computer': 1, 'humorously': 1, 'hundred': 1, 'hungry': 1, 'hurd': 1, 'huxley': 1, 'hybrid': 1, 'hybrids—can': 1, 'hyperintelligence': 1, 'hyperintelligent': 1, 'hypothesis': 3, 'hypothetical': 5, 'ibm': 4, 'idea': 4, 'identical': 2, 'identification': 1, 'identified': 2, 'identifies': 2, 'identify': 2, 'identifying': 1, 'idiosyncratic': 1, 'igor': 2, 'illustrate': 2, 'image': 8, 'imagenet': 1, 'images': 2, 'imitate': 2, 'imitated': 1, 'imitation': 1, 'immediately': 1, 'immunosuppressant': 1, 'impact': 1, 'imperfect': 2, 'implementation': 1, 'implementations': 1, 'implemented': 1, 'implicit': 2, 'implicitly': 2, 'implies': 1, 'important': 1, 'impossible': 2, 'impoverished': 1, 'imprecise': 1, 'improve': 4, 'improved': 3, 'improvement': 1, 'improvements': 2, 'improving': 3, 'inception': 1, 'include': 22, 'included': 1, 'includes': 5, 'including': 10, 'incomplete': 2, 'incomprehensible': 1, 'inconsistent': 1, 'incorporate': 1, 'incorporated': 2, 'increase': 9, 'increased': 3, 'increasing': 7, 'increasingly': 3, 'incrementally': 1, 'independent': 1, 'indexing': 1, 'india': 1, 'indicating': 1, 'indistinguishable': 1, 'individual': 2, 'individualized': 2, 'individuals': 2, 'induce': 1, 'induced': 2, 'inductive': 1, 'industrial': 3, 'industry': 6, 'inference': 5, 'inferences': 6, 'inferring': 1, 'infinite': 2, 'influence': 1, 'influenced': 1, 'influences': 2, 'influencing': 1, 'influenza': 3, 'information': 15, 'informs': 1, 'infrared': 1, 'infrastructure': 1, 'initial': 1, 'initiative': 1, 'innately': 1, 'innovation': 1, 'input': 8, 'inputs': 6, 'inserting': 1, 'inside': 2, 'insight': 2, 'inspiration': 1, 'inspired': 7, 'instance': 2, 'instead': 6, 'instinct': 1, 'institute': 4, 'institutions': 3, 'instructions': 1, 'insufficient': 1, 'integrated': 1, 'integrating': 1, 'integration': 3, 'intellectual': 2, 'intelligence': 119, 'intelligent': 33, 'intelligently': 3, 'intended': 1, 'intent': 1, 'intentionally': 1, 'intentions': 1, 'interacting': 1, 'interaction': 4, 'interactions': 2, 'interdisciplinary': 1, 'interest': 2, 'interested': 1, 'interesting': 1, 'interface': 1, 'interfaces': 1, 'interior': 1, 'internal': 1, 'intern
way': 8, 'ways': 4, 'wealthy': 1, 'weapons': 2, 'web': 3, 'weighing': 1, 'weight': 1, 'weighted': 2, 'weights': 2, 'weizenbaum': 3, 'well': 21, 'wellpublicized': 1, 'welltrained': 1, 'wellunderstood': 1, 'wendell': 1, 'werbos': 1, 'west': 1, 'whatever': 3, 'wheels': 1, 'wherein': 2, 'whether': 11, 'white': 2, 'whitecollar': 1, 'whose': 3, 'wide': 1, 'widely': 7, 'widespread': 2, 'widrow': 1, 'wielding': 1, 'wiener': 1, 'willing': 1, 'willshaw': 1, 'wins': 2, 'winter': 2, 'wire': 2, 'wireless': 1, 'wisdom': 2, 'within': 6, 'without': 6, 'women': 2, 'word': 4, 'words': 2, 'work': 13, 'worked': 4, 'working': 4, 'works': 4, 'workshop': 1, 'works—some': 1, 'world': 10, 'worldwide': 1, 'worry': 2, 'worrying': 1, 'worth': 2, 'would': 36, 'write': 2, 'writer': 1, 'writes': 1, 'writing': 1, 'written': 1, 'wrong': 1, 'wrote': 1, 'x': 2, 'xbox': 3, 'yang': 1, 'yann': 1, 'year': 3, 'years': 8, 'yet': 3, 'york': 1, 'young': 2, 'zalta': 1, 'zdnet': 1, 'zuckerberg': 1, 'čapek': 2}, 'machine_learning.txt': {'1960s': 1, '1970s': 1, '1980s': 1, '1990s': 2, 'abandoned': 1, 'ability': 3, 'able': 3, 'abnormal': 1, 'absence': 1, 'abstract': 1, 'abuse': 1, 'academic': 2, 'access': 1, 'accomplish': 1, 'according': 3, 'accordingly': 1, 'accuracy': 7, 'accurate': 1, 'accurately': 1, 'achieving': 1, 'acquire': 1, 'acquisition': 1, 'across': 2, 'action': 2, 'actions': 2, 'active': 2, 'activities': 1, 'activity': 1, 'actual': 1, 'acyclic': 2, 'adaptive': 1, 'addition': 5, 'additional': 2, 'addressed': 1, 'adhere': 1, 'adjusts': 1, 'adopted': 2, 'advanced': 1, 'advantage': 1, 'advice': 1, 'advices': 1, 'agents': 1, 'aggregate': 1, 'aggregated': 2, 'agrawal': 1, 'ai': 11, 'aics': 1, 'aim': 2, 'alan': 1, 'algorithm': 20, 'algorithmic': 4, 'algorithmically': 1, 'algorithms': 44, 'allow': 1, 'allowing': 1, 'allows': 2, 'along': 1, 'already': 2, 'also': 17, 'alternative': 1, 'although': 2, 'american': 1, 'among': 2, 'amount': 1, 'analogous': 1, 'analysis': 12, 'analytics': 1, 'and—most': 1, 'animal': 1, 'ann': 3, 'anns': 1, 'anomalies': 2, 'anomalous': 1, 'anomaly': 6, 'another': 1, 'answers': 2, 'applicants': 2, 'application': 4, 'applications': 5, 'applied': 4, 'apply': 2, 'approach': 8, 'approaches': 9, 'appropriately': 1, 'approximately': 1, 'area': 3, 'areas': 1, 'argued': 1, 'argues': 1, 'arises': 1, 'around': 1, 'array': 2, 'art': 2, 'arthur': 1, 'artificial': 23, 'artists': 1, 'arun': 1, 'assert': 1, 'assess': 1, 'assessment': 1, 'assessments': 1, 'assign': 1, 'assigned': 1, 'assignment': 1, 'associated': 4, 'association': 6, 'assume': 1, 'assumed': 1, 'assumption': 1, 'assumptions': 2, 'attempt': 3, 'attempted': 1, 'attempts': 2, 'attention': 1, 'auc': 1, 'autoencoders': 1, 'automated': 2, 'automatically': 1, 'autonomous': 1, 'available': 1, 'awarded': 1, 'away': 1, 'b': 1, 'back': 1, 'background': 2, 'backpropagated': 1, 'backpropagation': 1, 'badly': 1, 'bank': 1, 'based': 6, 'basic': 1, 'basis': 2, 'basket': 1, 'bayesian': 6, 'become': 1, 'beginning': 1, 'behaves': 1, 'behavior': 3, 'behavioral': 2, 'belief': 1, 'belonging': 1, 'belongs': 1, 'best': 4, 'better': 2, 'bias': 6, 'biased': 1, 'biases': 10, 'bias–variance': 1, 'big': 1, 'billions': 1, 'binary': 1, 'bioinformatics': 2, 'biological': 3, 'biology': 1, 'black': 2, 'board': 1, 'book': 3, 'bootstrap': 1, 'borrowed': 1, 'bounds': 2, 'brain': 4, 'brains': 1, 'branch': 1, 'branches': 2, 'breiman': 1, 'broad': 2, 'build': 3, 'builds': 1, 'built': 3, 'burger': 1, 'bursts': 1, 'business': 1, 'buy': 1, 'buys': 1, 'caa': 4, 'call': 2, 'called': 10, 'came': 1, 'capable': 1, 'captured': 1, 'car': 1, 'care': 4, 'cases': 2, 'categories': 3, 'categorisation': 1, 'categorized': 1, 'category': 1, 'caused': 1, 'central': 1, 'centralized': 1, 'certain': 3, 'challenges': 2, 'challenging': 1, 'changed': 2, 'chaos': 1, 'characteristic': 3, 'characters': 1, 'chatbot': 1, 'cheaper': 1, 'chosen': 1, 'cinematch': 1, 'class': 7, 'classes': 1, 'classic': 1, 'classification': 18, 'classifications': 1, 'classified': 1, 'classifier': 4, 'clean': 1, 'closely': 3, 'cluster': 5, 'clustering': 3, 'clusters': 3, 'coding': 1, 'cofounder': 1, 'cognition': 1, 'cognitive': 1, 'coined': 1, 'collaboration': 1, 'collect': 1, 'collected': 2, 'collection': 3, 'collectively': 2, 'collision': 1, 'combination': 1, 'combine': 1, 'combined': 1, 'come': 2, 'comes': 1, 'coming': 1, 'common': 4, 'commonalities': 2, 'commonly': 2, 'communities': 1, 'compactness': 1, 'company': 1, 'comparison': 1, 'competition': 1, 'completely': 1, 'complex': 2, 'complexity': 5, 'component': 3, 'components': 1, 'computation': 2, 'computational': 4, 'computationally': 1, 'compute': 2, 'computed': 1, 'computer': 13, 'computers': 4, 'computes': 1, 'computing': 2, 'concept': 1, 'concern': 1, 'concerned': 3, 'concerns': 1, 'conclusions': 1, 'conditional': 1, 'conference': 2, 'conferences': 2, 'configurations': 1, 'confusion': 1, 'conjunction': 1, 'conjunctions': 1, 'connected': 2, 'connection': 3, 'connectionism': 1, 'connectionist': 1, 'connections': 1, 'connectivity': 1, 'consequence': 4, 'consider': 1, 'considerable': 1, 'considered': 2, 'considering': 2, 'considers': 1, 'consists': 2, 'constitute': 1, 'constitutional': 1, 'constraint': 2, 'construct': 1, 'contain': 2, 'containing': 1, 'contains': 3, 'context': 3, 'contextdependent': 1, 'contexts': 1, 'continue': 2, 'continued': 2, 'continuous': 2, 'contrast': 2, 'control': 1, 'convenient': 1, 'conventional': 1, 'conventionally': 1, 'conversely': 1, 'core': 1, 'corpora': 1, 'corpus': 1, 'correct': 2, 'correctly': 2, 'corresponding': 1, 'could': 2, 'course': 2, 'crash': 1, 'create': 2, 'created': 2, 'creating': 1, 'criminal': 1, 'crisis': 1, 'criteria': 1, 'criterion': 1, 'critical': 1, 'crossbar': 3, 'crosses': 1, 'crossover': 1, 'crossvalidation': 1, 'cultural': 1, 'cumulative': 1, 'cumulatively': 1, 'current': 1, 'curriculum': 1, 'curve': 1, 'customer': 2, 'customers': 1, 'dag': 1, 'daniel': 1, 'data': 79, 'database': 2, 'databases': 3, 'datagenerating': 1, 'dataset': 1, 'datasets': 1, 'days': 1, 'dealing': 2, 'decades': 1, 'decentralizes': 1, 'decentralizing': 1, 'decision': 11, 'decisions': 4, 'decomposition': 1, 'decreases': 2, 'deep': 4, 'defect': 1, 'define': 1, 'defined': 2, 'defining': 2, 'definition': 4, 'deliver': 2, 'delivers': 1, 'denoising': 1, 'denominators': 2, 'density': 3, 'depending': 1, 'derive': 1, 'described': 1, 'describes': 1, 'designation': 1, 'designed': 2, 'desirable': 1, 'desired': 3, 'detect': 3, 'detection': 11, 'determine': 3, 'develop': 2, 'developed': 1, 'developmental': 1, 'deviations': 2, 'devices': 1, 'diagnose': 1, 'diagnosis': 2, 'diagnostic': 2, 'diagrams': 1, 'dictionary': 10, 'differ': 1, 'difference': 3, 'different': 7, 'differing': 1, 'difficult': 2, 'digitizing': 1, 'digits': 1, 'dilemma': 1, 'dimensional': 1, 'dimensionality': 1, 'directed': 2, 'directly': 1, 'discipline': 2, 'disciplines': 2, 'discover': 2, 'discovered': 1, 'discovering': 5, 'discovery': 5, 'discrepancy': 1, 'discrete': 1, 'diseases': 2, 'disentangles': 1, 'displaystyle': 1, 'dissimilar': 1, 'distinct': 1, 'distinguished': 1, 'distribution': 3, 'divided': 1, 'doctors': 1, 'documentation': 1, 'domains': 3, 'dominant': 1, 'dominate': 1, 'done': 1, 'dr': 1, 'drawn': 2, 'draws': 1, 'driven': 1, 'driving': 1, 'duda': 1, 'due': 2, 'duplicating': 1, 'dynamic': 3, 'e': 4, 'early': 3, 'easily': 1, 'ecml': 1, 'edges': 2, 'editions': 1, 'effective': 4, 'efficiency': 1, 'efficient': 1, 'efficiently': 1, 'ehud': 1, 'either': 3, 'email': 3, 'emails': 1, 'emotion': 3, 'emotions': 2, 'emphasis': 1, 'employ': 1, 'employed': 2, 'employs': 2, 'enables': 1, 'encoding': 1, 'encompasses': 2, 'encountered': 1, 'end': 1, 'endeavor': 1, 'engine': 1, 'engineering': 1, 'engineers': 1, 'ensemble': 1, 'entails': 1, 'entities': 1, 'environment': 9, 'environments': 1, 'enwikipediaorgwikimachinelearning': 1, 'error': 2, 'errors': 1, 'especially': 2, 'estimate': 1, 'estimated': 1, 'estimation': 2, 'ethical': 3, 'ethics': 1, 'evaluated': 3, 'evaluates': 1, 'evaluation': 2, 'even': 3, 'events': 1, 'every': 1, 'everything': 1, 
impacts': 1, 'implausible': 1, 'implementation': 1, 'implementations': 1, 'implicitly': 2, 'importantly—it': 1, 'imprecise': 1, 'improve': 5, 'improvement': 1, 'improves': 2, 'improving': 1, 'include': 7, 'including': 5, 'incomegenerating': 1, 'incoming': 1, 'increased': 1, 'increases': 2, 'increasing': 2, 'increasingly': 1, 'independence': 1, 'independent': 1, 'indicate': 1, 'indicators': 1, 'individual': 2, 'induction': 2, 'inductive': 6, 'inductively': 1, 'infeasible': 2, 'inference': 2, 'inferences': 1, 'inferred': 1, 'influence': 1, 'influences': 1, 'information': 7, 'inherently': 1, 'inherited': 1, 'initial': 2, 'initially': 1, 'input': 15, 'inputs': 12, 'inspired': 2, 'instance': 2, 'instances': 5, 'instead': 3, 'intelligence': 9, 'intelligent': 1, 'intended': 2, 'interaction': 2, 'interacts': 1, 'interest': 2, 'interested': 1, 'interesting': 1, 'interestingness': 1, 'internal': 1, 'international': 2, 'intimate': 1, 'introduced': 2, 'introduces': 1, 'intrusion': 2, 'investigators': 2, 'investment': 1, 'involves': 3, 'involving': 1, 'issue': 1, 'issues': 1, 'item': 2, 'items': 3, 'iteration': 1, 'iterative': 1, 'job': 2, 'jobs': 1, 'joint': 1, 'jordan': 1, 'journal': 2, 'journals': 2, 'k': 2, 'k1': 1, 'kdd': 2, 'kernel': 3, 'key': 3, 'kfoldcrossvalidation': 1, 'khosla': 1, 'killed': 1, 'kind': 1, 'kinds': 2, 'knowledge': 11, 'knowledgebased': 1, 'known': 11, 'ksvd': 1, 'label': 1, 'labeled': 6, 'labelled': 1, 'labels': 7, 'labsresearch': 1, 'lack': 3, 'laid': 1, 'language': 4, 'languages': 2, 'large': 3, 'larger': 1, 'largescale': 1, 'last': 1, 'later': 1, 'latter': 1, 'layer': 4, 'layers': 4, 'lcs': 1, 'lead': 2, 'leading': 3, 'learn': 11, 'learned': 10, 'learner': 3, 'learning': 176, 'learns': 4, 'least': 3, 'leaves': 2, 'leaving': 1, 'leo': 1, 'less': 2, 'letters': 1, 'levels': 1, 'li': 1, 'light': 1, 'like': 5, 'likelihood': 1, 'likely': 2, 'limitations': 1, 'limited': 2, 'line': 3, 'linear': 5, 'links': 1, 'logic': 7, 'logical': 3, 'logistic': 1, 'long': 1, 'longer': 1, 'longstanding': 1, 'looking': 1, 'loosely': 1, 'loss': 4, 'lost': 1, 'lot': 1, 'lowdimensional': 2, 'lowerlevel': 1, 'machine': 94, 'machinelearning': 2, 'machinery': 1, 'machines': 8, 'made': 1, 'main': 1, 'maintained': 1, 'major': 1, 'majority': 2, 'make': 5, 'makes': 1, 'making': 3, 'manifold': 1, 'manipulate': 1, 'manmade': 1, 'manner': 1, 'manual': 1, 'manually': 1, 'many': 12, 'map': 1, 'mapping': 1, 'maps': 1, 'marked': 1, 'market': 1, 'marketing': 1, 'markov': 1, 'match': 1, 'mathematical': 8, 'mathematically': 1, 'mathematics': 1, 'mathrm': 2, 'matrix': 4, 'maturation': 1, 'maximise': 1, 'maximize': 1, 'may': 9, 'mdp': 2, 'meaning': 2, 'means': 2, 'measure': 2, 'measured': 1, 'measures': 1, 'meat': 1, 'mechanisms': 1, 'mediaservices': 1, 'medical': 5, 'medicate': 1, 'medication': 1, 'members': 2, 'memory': 2, 'mentioned': 2, 'meta': 1, 'method': 9, 'methodological': 1, 'methods': 18, 'metric': 1, 'michael': 1, 'microclusters': 1, 'microsoft': 2, 'microsystems': 1, 'mid1980s': 1, 'might': 1, 'million': 1, 'mimics': 1, 'minimization': 1, 'minimize': 1, 'minimizing': 1, 'mining': 12, 'missing': 1, 'mitchell': 1, 'mitigate': 1, 'ml': 1, 'mloss': 1, 'mobile': 1, 'model': 34, 'modeling': 3, 'models': 15, 'mostly': 2, 'motivated': 1, 'motor': 1, 'moved': 1, 'movie': 1, 'much': 2, 'multiagent': 1, 'multidimensional': 1, 'multilayer': 1, 'multilinear': 1, 'multiple': 3, 'must': 1, 'mutation': 1, 'n': 3, 'name': 1, 'named': 1, 'natural': 2, 'nature': 5, 'navigates': 1, 'neatly': 1, 'necessarily': 2, 'needed': 5, 'needing': 1, 'needs': 2, 'negative': 5, 'neither': 1, 'netflix': 3, 'network': 9, 'networks': 12, 'neural': 12, 'neuron': 3, 'neurons': 8, 'new': 10, 'next': 1, 'nilsson': 1, 'nodes': 1, 'noise': 2, 'noisy': 1, 'nonlinear': 3, 'nonlinearity': 1, 'nonprobabilistic': 1, 'nonwhite': 1, 'normal': 4, 'nothing': 1, 'notion': 1, 'novelties': 1, 'nphard': 1, 'nt': 1, 'number': 1, 'numbers': 2, 'numerators': 2, 'numerical': 1, 'numerous': 1, 'object': 1, 'objective': 2, 'objects': 3, 'observations': 5, 'observed': 2, 'obtain': 1, 'occurrences': 1, 'offers': 1, 'often': 12, 'one': 14, 'ones': 1, 'ongoing': 1, 'onions': 2, 'opensource': 3, 'operating': 3, 'operational': 1, 'operations': 1, 'opponent': 2, 'optimal': 1, 'optimization': 6, 'order': 5, 'ordinary': 1, 'original': 1, 'ought': 1, 'outlier': 4, 'outliers': 1, 'outperformed': 1, 'output': 8, 'outputs': 6, 'outside': 2, 'overall': 2, 'overfitting': 3, 'overlap': 1, 'overview': 1, 'owners': 1, 'p': 3, 'paintings': 1, 'paper': 1, 'paradigm': 1, 'paradigms': 1, 'part': 3, 'particular': 3, 'particularly': 1, 'partitions': 1, 'patch': 1, 'paths': 1, 'patients': 2, 'pattern': 4, 'patterns': 4, 'pedestrian': 1, 'people': 7, 'perceptrons': 2, 'perform': 12, 'performance': 10, 'performed': 1, 'performing': 5, 'personal': 2, 'philosophical': 1, 'phones': 1, 'photos': 1, 'pick': 1, 'picked': 1, 'piece': 1, 'piecewise': 1, 'pioneer': 1, 'pkdd': 1, 'placeholder': 1, 'placements': 1, 'plagued': 1, 'plan': 1, 'platt': 1, 'play': 1, 'playing': 2, 'plotkin': 1, 'pointofsale': 1, 'points': 1, 'policies': 1, 'polynomial': 4, 'poorer': 1, 'popular': 1, 'population': 1, 'pos': 1, 'poses': 1, 'positive': 5, 'possible': 1, 'possibly': 1, 'potatoes': 2, 'potential': 2, 'powerful': 1, 'practical': 2, 'practice': 1, 'practitioners': 1, 'pragmatic': 1, 'preassigned': 1, 'predesignated': 1, 'predict': 5, 'predicted': 1, 'prediction': 3, 'predictions': 8, 'predictive': 4, 'predicts': 1, 'preferences': 1, 'prehistory': 1, 'prejudices': 1, 'preprocessing': 2, 'presence': 2, 'present': 1, 'presented': 1, 'preserve': 1, 'previous': 1, 'previously': 6, 'pricing': 1, 'principal': 2, 'principles': 1, 'privacy': 2, 'prize': 3, 'probabilistic': 6, 'probabilities': 1, 'probability': 3, 'problem': 7, 'problems': 11, 'proceeds': 1, 'process': 7, 'processes': 2, 'processing': 2, 'produce': 2, 'product': 1, 'production': 1, 'products': 1, 'professionals': 2, 'profits': 1, 'profound': 1, 'program': 6, 'programmed': 3, 'programmers': 1, 'programming': 8, 'programs': 3, 'prolog': 1, 'promotional': 1, 'propelling': 1, 'proper': 1, 'properties': 2, 'property': 1, 'proposal': 1, 'proprietary': 3, 'protein': 1, 'provide': 2, 'provided': 3, 'provider': 1, 'provides': 1, 'proving': 1, 'public': 1, 'published': 1, 'quantify': 1, 'query': 1, 'quest': 1, 'question': 2, 'questions': 1, 'quickly': 1, 'quite': 1, 'quoted': 1, 'r': 2, 'racist': 2, 'raise': 1, 'rakesh': 1, 'random': 2, 'randomly': 1, 'range': 1, 'ranking': 1, 'rare': 3, 'rate': 4, 'rates': 2, 'rather': 3, 'ratings': 1, 'ratios': 1, 'react': 1, 'reading': 1, 'real': 3, 'realized': 1, 'realworld': 1, 'reasoning': 1, 'reasons': 1, 'rebellion': 1, 'receive': 1, 'receiver': 1, 'receives': 2, 'receiving': 1, 'recognition': 4, 'recognize': 2, 'recognizing': 1, 'recommendation': 4, 'reconstruction': 1, 'recorded': 1, 'recovery': 1, 'reducing': 1, 'reduction': 1, 'references': 1, 'referred': 2, 'refers': 1, 'regression': 12, 'regularities': 1, 'regularization': 1, 'reinforcement': 9, 'reinvention': 1, 'reinventions': 1, 'related': 9, 'relation': 4, 'relational': 1, 'relationship': 1, 'relationships': 3, 'relying': 1, 'remainder': 1, 'remaining': 1, 'remains': 1, 'reminds': 1, 'remove': 1, 'reorganized': 1, 'replaced': 1, 'replacement': 1, 'replaces': 1, 'report': 3, 'reported': 1, 'reportedly': 1, 'represent': 7, 'representation': 7, 'representations': 4, 'representative': 3, 'represented': 10, 'representing': 2, 'represents': 1, 'reproduce': 1, 'require': 3, 'research': 8, 'researched': 1, 'researchers': 4, 'reshaping': 1, 'resolved': 1, 'resources': 1, 'respect': 3, 'respectively': 2, 'responding': 1, 'response': 1, 'responsibility': 1, 'responsible': 1, 'restricted': 1, 'resulting': 2, 'results': 4, 'retrieval': 1, 'reveal': 1, 'revealed': 1, 'reward': 1, 'rewards': 2, 'ridge': 1, 'rift': 1, 'rightarrow': 1, 'risk': 1, 'robot': 2, 'robotics': 1, 'robots': 1, 'roc': 2, 'routine': 1, 'rule': 5, 'rulebased': 5, 'rulelearning': 1, 'rules': 10, 'rumelhart': 1, 'runs': 1, 'said': 2, 's
tools': 2, 'topic': 1, 'total': 1, 'toward': 2, 'towards': 1, 'tpr': 1, 'tracking': 1, 'train': 1, 'trained': 7, 'training': 45, 'transaction': 2, 'transactions': 1, 'transform': 1, 'transformations': 1, 'transformative': 1, 'translation': 1, 'transmit': 1, 'travel': 1, 'traversing': 1, 'tree': 7, 'trees': 4, 'trendline': 1, 'trick': 2, 'tries': 2, 'true': 3, 'turing': 1, 'turn': 1, 'twitter': 1, 'two': 8, 'type': 2, 'types': 4, 'typical': 1, 'typically': 7, 'u': 1, 'uber': 1, 'unavailability': 1, 'unbalanced': 1, 'uncertain': 1, 'uncertainty': 1, 'unconscious': 1, 'underlying': 2, 'understand': 1, 'undesirable': 1, 'unexpected': 1, 'uniform': 1, 'uninformed': 1, 'united': 1, 'units': 1, 'universally': 1, 'unknown': 4, 'unlabeled': 3, 'unless': 1, 'unnecessary': 1, 'unrecognized': 1, 'unseen': 3, 'unsupervised': 16, 'update': 1, 'updates': 1, 'upon': 1, 'usage': 1, 'use': 10, 'used': 25, 'useful': 2, 'user': 1, 'users': 3, 'uses': 4, 'using': 11, 'usually': 4, 'utilization': 1, 'v': 2, 'vaguely': 1, 'valid': 1, 'validated': 1, 'value': 3, 'values': 3, 'variable': 2, 'variables': 5, 'variation': 1, 'varied': 1, 'variety': 4, 'various': 5, 'vast': 1, 'vector': 6, 'vectors': 1, 'vehicle': 1, 'vehicles': 1, 'verification': 2, 'video': 2, 'viewers': 1, 'viewing': 1, 'vinod': 1, 'vision': 4, 'visual': 1, 'visually': 1, 'w': 4, 'wall': 1, 'wants': 1, 'watch': 1, 'watson': 1, 'way': 4, 'weakly': 1, 'web': 1, 'weight': 2, 'well': 4, 'wellordered': 1, 'wherefrom': 1, 'wherein': 1, 'whether': 1, 'wide': 1, 'widely': 1, 'win': 1, 'within': 4, 'without': 7, 'work': 3, 'workaround': 1, 'would': 6, 'wrong': 1, 'wrote': 1, 'years': 1, 'yet': 2, 'yield': 1, 'yielded': 1, 'zeros': 1}, 'natural_language_processing.txt': {'1950s': 1, '1960s': 1, '1970s': 1, '1980s': 4, '2010s': 1, 'abbreviations': 1, 'able': 2, 'accents': 1, 'accidentally': 1, 'accurate': 3, 'achieve': 1, 'acts': 1, 'adjective': 1, 'adjectives': 1, 'advantage': 2, 'advantages': 1, 'agglutinated': 1, 'aicomplete': 2, 'aid': 4, 'alan': 1, 'algorithm': 1, 'algorithms': 9, 'alignment': 1, 'allows': 1, 'almost': 1, 'alpac': 1, 'also': 11, 'although': 2, 'ambiguity': 3, 'ambiguous': 1, 'among': 2, 'amount': 2, 'amounts': 2, 'analog': 1, 'analyses': 1, 'analysis': 5, 'analyze': 1, 'anaphora': 1, 'annotated': 1, 'annotation': 1, 'annotations': 1, 'another': 2, 'answer': 2, 'answering': 2, 'answers': 2, 'applications': 1, 'applied': 1, 'approach': 2, 'approaches': 2, 'arabic': 1, 'areas': 1, 'article': 1, 'articles': 1, 'artificial': 2, 'assertion': 1, 'associated': 1, 'assumption': 2, 'assumptions': 1, 'attaching':
equivalent': 1, 'erroneous': 1, 'errorprone': 1, 'errors': 1, 'especially': 5, 'etc': 3, 'european': 1, 'evaluations': 1, 'even': 2, 'example': 7, 'examples': 3, 'exceeded': 1, 'existing': 2, 'expectations': 1, 'expected': 1, 'experiment': 1, 'explanation': 1, 'explicit': 1, 'express': 1, 'expression': 2, 'expressions': 1, 'extract': 2, 'extraction': 3, 'extremely': 2, 'fact': 2, 'facts': 1, 'failed': 1, 'fairly': 2, 'false': 1, 'fashion': 1, 'feature': 1, 'features': 2, 'field': 1, 'financial': 1, 'find': 1, 'first': 3, 'firstorder': 1, 'five': 2, 'flight': 1, 'flurry': 1, 'focus': 1, 'focused': 3, 'focuses': 2, 'following': 1, 'form': 4, 'formal': 2, 'formalization': 2, 'forms': 2, 'found': 2, 'fragments': 1, 'french': 1, 'frequently': 2, 'front': 3, 'fulfill': 1, 'fully': 1, 'funding': 1, 'furthermore': 1, 'general': 1, 'generally': 6, 'generate': 1, 'generated': 1, 'generation': 2, 'generic': 1, 'georgetown': 1, 'german': 1, 'given': 19, 'goal': 1, 'gone': 1, 'government': 1, 'governmental': 1, 'gracefully': 1, 'gradual': 1, 'grammar': 7, 'grammars': 1, 'grammatical': 1, 'great': 1, 'greatly': 1, 'grouped': 1, 'hand': 1, 'handannotated': 1, 'handcoding': 1, 'handcrafted': 1, 'handling': 1, 'handproduced': 1, 'handwritten': 6, 'hard': 2, 'hardly': 1, 'head': 2, 'heavily': 1, 'heuristic': 1, 'hidden': 1, 'higherlevel': 1, 'highly': 1, 'history': 2, 'house': 2, 'however': 11, 'https': 1, 'human': 6, 'humanlanguage': 1, 'humanlike': 1, 'humans': 1, 'hurts': 2, 'ibm': 1, 'identical': 1, 'identification': 1, 'identified': 1, 'identify': 3, 'identifying': 3, 'ie': 3, 'ifthen': 2, 'ignore': 1, 'image': 1, 'impaired': 1, 'implemented': 1, 'implicit': 1, 'inaccurate': 1, 'include': 1, 'included': 1, 'includes': 2, 'including': 2, 'increase': 3, 'increases': 1, 'increasing': 1, 'increasingly': 3, 'indian': 1, 'individual': 2, 'induction': 1, 'inference': 2, 'inferior': 1, 'inflected': 1, 'inflection': 1, 'inflectional': 3, 'information': 6, 'input': 13, 'instance': 1, 'instead': 2, 'insufficient': 1, 'integrated': 1, 'intelligence': 4, 'intended': 2, 'intents': 1, 'interaction': 1, 'interactions': 1, 'intermediate': 2, 'intertwined': 1, 'introduced': 1, 'introduction': 2, 'involve': 1, 'involved': 1, 'involves': 1, 'involving': 1, 'items': 1, 'jabberwacky': 1, 'japanese': 1, 'john': 2, 'joseph': 1, 'knowledge': 3, 'known': 3, 'language': 38, 'languageprocessing': 1, 'languages': 12, 'large': 3, 'larger': 4, 'late': 3, 'law': 1, 'laws': 1, 'learn': 4, 'learning': 13, 'learningbased': 1, 'least': 1, 'lehnert': 2, 'lemma': 1, 'lemmatization': 1, 'less': 1, 'lessening': 1, 'letter': 1, 'letters': 1, 'lexical': 1, 'life': 1, 'like': 4, 'limit': 1, 'limitation': 1, 'limited': 1, 
': 4, 'recent': 2, 'recognition': 9, 'recognize': 1, 'recognizing': 3, 'reduced': 1, 'reducing': 1, 'refer': 2, 'references': 1, 'referred': 2, 'referring': 2, 'regardless': 1, 'related': 1, 'relationship': 2, 'relationships': 4, 'relative': 1, 'relevant': 1, 'reliable': 2, 'relied': 1, 'rely': 1, 'relying': 1, 'removing': 1, 'report': 1, 'representation': 3, 'representations': 2, 'representing': 2, 'requires': 1, 'requiring': 2, 'research': 9, 'researched': 1, 'resolution': 3, 'resource': 1, 'responding': 1, 'response': 1, 'restricted': 2, 'result': 2, 'results': 6, 'return': 1, 'reviews': 1, 'revolution': 2, 'right': 1, 'road': 1, 'robust': 2, 'rogerian': 1, 'root': 2, 'rubric': 1, 'rulebased': 1, 'rules': 16, 'russian': 1, 'sam': 1, 'say': 1, 'schank': 1, 'science': 1, 'scripts': 1, 'section': 1, 'see': 6, 'seem': 1, 'seen': 1, 'segment': 1, 'segmentation': 6, 'segments': 1, 'select': 1, 'semantic': 4, 'semantics': 7, 'semisupervised': 1, 'sense': 2, 'senses': 1, 'sentence': 11, 'sentences': 3, 'sentiment': 2, 'separate': 7, 'separated': 1, 'sequencetosequence': 1, 'serve': 4, 'set': 5, 'sets': 1, 'several': 2, 'shift': 1, 'showing': 1, 'shrdlu': 1, 'signal': 1, 'significant': 2, 'similar': 2, 'simple': 1, 'simply': 3, 'simulation': 1, 'since': 2, 'sixty': 2, 'slower': 1, 'small': 1, 'smt': 1, 'socalled': 2, 'social': 1, 'soft': 3, 'software': 1, 'solutions': 1, 'solve': 1, 'solved': 1, 'solving': 1, 'sometimes': 4, 'sort': 1, 'sound': 2, 'sounds': 1, 'spaces': 1, 'span': 1, 'spanish': 1, 'speaking': 2, 'specific': 3, 'specifically': 2, 'speech': 16, 'spoken': 3, 'started': 1, 'starting': 1, 'startlingly': 1, 'statement': 1, 'stateoftheart': 1, 'statistical': 11, 'steady': 1, 'stemming': 2, 'steps': 1, 'stochastic': 1, 'stream': 1, 'structure': 3, 'structured': 1, 'structures': 2, 'subdivided': 1, 'subfield': 1, 'subjective': 2, 'substantial': 1, 'subtask': 2, 'subtasks': 2, 'success': 1, 'successes': 1, 'successful': 1, 'successive': 2, 'successively': 1, 'summaries': 1, 'summarization': 1, 'summary': 1, 'supervised': 1, 'supplying': 1, 'surprisingly': 1, 'syntax': 2, 'system': 3, 'systems': 21, 'table': 1, 'tagging': 3, 'take': 2, 'takes': 1, 'talespin': 1, 'task': 11, 'tasks': 10, 'techniques': 2, 'tenyearlong': 1, 'term': 1, 'termed': 3, 'terminology': 2, 'terms': 2, 'test': 1, 'text': 19, 'texttospeech': 2, 'textual': 4, 'thai': 1, 'theoretical': 1, 'theories': 1, 'things': 2, 'though': 1, 'thought': 1, 'thousands': 2, 'three': 1, 'thus': 2, 'time': 2, 'timeconsuming': 1, 'titled': 1, 'tonal': 1, 'topic': 3, 'transform': 1, 'transformational': 1, 'transformations': 1, 'translate': 1, 'translation': 11, 'tree': 2, 'trees': 2, 'trends': 1, 'trivial': 1, 'true': 2, 'truefalse': 1, 'turing': 2, 'turkish': 1, 'two': 2, 'type': 3, 'types': 2, 'typical': 4, 'typically': 3, 'underlies': 1, 'underpinnings': 1, 'understanding': 3, 'unfamiliar': 2, 'union': 1, 'units': 2, 'unmanageable': 1, 'unsupervised': 1, 'upon': 1, 'use': 4, 'used': 7, 'useful': 1, 'using': 5, 'usually': 3, 'variety': 1, 'verb': 2, 'verbalization': 1, 'via': 1, 'viewed': 1, 'visually': 1, 'vocabularies': 1, 'vocabulary': 1, 'vs': 3, 'web': 1, 'weights': 2, 'weizenbaum': 1, 'whereas': 2, 'whether': 1, 'whose': 1, 'wide': 2, 'widespread': 1, 'wilensky': 1, 'within': 2, 'without': 2, 'word': 10, 'wordnet': 1, 'words': 23, 'work': 3, 'worked': 1, 'working': 1, 'works': 1, 'world': 2, 'worlds': 1, 'would': 1, 'write': 1, 'writing': 2, 'written': 3, 'years': 1, 'yesno': 2}, 'neural_network.txt': {'1940s': 1, '1980s': 1, '3d': 2, 'abandoning': 1, 'ability': 3, 'abstract': 1, 'accelerate': 1, 'accelerators': 1, 'accomplish': 1, 'according': 2, 'accumulating': 1, 'accuracy': 4, 'achieve': 1, 'across': 2, 'act': 1, 'action': 5, 'actions': 6, 'activation': 6, 'activities': 2, 'actor': 1, 'actors': 1, 'actually': 1, 'acyclic': 1, 'ad': 3, 'adapt': 1, 'adaptation': 1, 'adaptive': 2, 'added': 1, 'additional': 1, 'address': 1, 'addresses': 1, 'adjust': 2, 'adjusted': 1, 'adjusting': 1, 'adjustment': 2, 'adjusts': 1, 'adopted': 1, 'advanced': 1, 'advances': 1, 'adversarial': 1, 'advice': 1, 'advocates': 1, 'agent': 2, 'aggregate': 1, 'aggregated': 1, 'aid': 1, 'aiding': 1, 'aim': 2, 'aimed': 1, 'aircraft': 1, 'al': 2, 'alexander': 1, 'algorithm': 11, 'algorithms': 4, 'allow': 4, 'allowed': 2, 'allowrequire': 1, 'allows': 2, 'almost': 3, 'along': 2, 'also': 10, 'alternating': 1, 'alternatively': 1, 'although': 1, 'among': 1, 'amount': 2, 'amounts': 1, 'analog': 1, 'analysis': 3, 'analyze': 1, 'analyzing': 2, 'anatomy': 1, 'andor': 1, 'android': 1, 'animal': 1, 'ann': 14, 'annealing': 1, 'anns': 17, 'another': 4, 'answer': 1, 'anything': 1, 'applicable': 1, 'application': 4, 'applications': 6, 'applied': 2, 'approach': 1, 'approaches': 5, 'approaching': 1, 'appropriate': 1, 'appropriately': 1, 'approximated': 1, 'approximating': 1, 'approximation': 4, 'approximator': 1, 'arbitrary': 2, 'architecture': 5, 'architectures': 1, 'areas': 1, 'argued': 1, 'arise': 2, 'arises': 2, 'around': 1, 'array': 1, 'art': 1, 'articulation': 1, 'artificial': 10, 'assigned': 1, 'assigning': 1, 'associated': 3, 'association': 1, 'assuming': 1, 'assumptions': 1, 'attempt': 1, 'attempts': 2, 'attention': 1, 'attributable': 1, 'aura': 1, 'authenticity': 1, 'autokeras': 1, 'automate': 1, 'automated': 1, 'automatic': 1, 
2, 'continuous': 2, 'control': 8, 'controller': 1, 'controllers': 1, 'conventional': 1, 'converge': 2, 'convergence': 4, 'convergent': 1, 'convexity': 1, 'convoluted': 1, 'convolutional': 2, 'correct': 2, 'corrective': 1, 'correspond': 2, 'corresponds': 2, 'cost': 22, 'costs': 1, 'could': 4, 'counterexamples': 1, 'coupled': 1, 'cover': 1, 'cpu': 1, 'create': 2, 'created': 3, 'creates': 1, 'creating': 1, 'credit': 2, 'critical': 1, 'criticism': 2, 'crossbar': 4, 'crosses': 1, 'crossvalidation': 1, 'cumulative': 1, 'curiosity': 1, 'cybersecurity': 1, 'data': 20, 'dataset': 1, 'david': 1, 'days': 1, 'dean': 1, 'deceiving': 1, 'decides': 1, 'deciding': 1, 'decision': 3, 'decisions': 1, 'declaration': 1, 'decline': 1, 'decreases': 2, 'deductions': 1, 'deep': 4, 'deeper': 1, 'define': 2, 'defined': 3, 'defines': 1, 'defining': 1, 'deformation': 1, 'degree': 1, 'delivered': 1, 'density': 1, 'depend': 1, 'dependencies': 1, 'dependent': 2, 'depending': 1, 'depends': 3, 'depth': 1, 'derivative': 1, 'derive': 1, 'derived': 3, 'descent': 2, 'described': 1, 'design': 4, 'designed': 2, 'designer': 1, 'desirable': 2, 'desired': 3, 'despite': 1, 'detecting': 3, 'detection': 1, 'determine': 1, 'determined': 1, 'determines': 1, 'development': 2, 'deviations': 1, 'devise': 1, 'devising': 1, 'dewdney': 3, 'diagnose': 1, 'diagnosis': 2, 'difference': 1, 'differences': 1, 'different': 2, 'differentiable': 2, 'differentiation': 1, 'difficulty': 1, 'digits': 1, 'dimension': 5, 'directed': 2, 'directing': 1, 'direction': 1, 'directly': 2, 'disasters': 1, 'disciplines': 1, 'discover': 1, 'discovered': 1, 'discrete': 1, 'discretization': 1, 'discriminate': 1, 'discussed': 1, 'displaying': 1, 'displaystyle': 13, 'distinct': 1, 'distinguish': 1, 'distributed': 1, 'distribution': 7, 'distributions': 2, 'diverse': 1, 'divided': 1, 'dock': 1, 'documents': 1, 'domain': 1, 'domains': 2, 'done': 3, 'dreyfus': 1, 'driven': 1, 'due': 1, 'dynamic': 3, 'dynamics': 1, 'e': 5, 'easier': 1, 'edges': 2, 'effective': 1, 'effectively': 1, 'eg': 3, 'electrical': 1, 'element': 1, 'eliminating': 1, 'email': 1, 'embody': 1, 'emergent': 1, 'emerges': 1, 'emotion': 3, 'emotions': 2, 'emphasizes': 2, 'emphatic': 1, 'empirical': 2, 'employed': 1, 'enabled': 2, 'encountered': 2, 'engineering': 2, 'engineers': 1, 'enormous': 1, 'entire': 1, 'environment': 9, 'environments': 1, 'enwikipediaorgwikineuralnetwork': 1, 'episode': 1, 'equal': 1, 'error': 15, 'errors': 3, 'especially': 2, 'estimate': 1, 'estimated': 1, 'estimation': 3, 'et': 2, 'etc': 1, 'evaluate': 1, 'evaluated': 1, 'even': 4, 'every': 2, 'evolutionary': 1, 'evolve': 1, 'evolved': 1, 'examining': 1, 'example': 11, 'examples': 7, 'exceeds': 1, 'exclusiveor': 1, '
ction': 1, 'recurrent': 2, 'recursion': 1, 'recursive': 1, 'redesigned': 1, 'reduce': 3, 'reduces': 1, 'reducing': 2, 'references': 1, 'referred': 1, 'refinements': 1, 'reflect': 1, 'regarding': 1, 'regression': 2, 'regularization': 2, 'reinforcement': 6, 'related': 4, 'relation': 1, 'relative': 1, 'relaying': 1, 'reliability': 2, 'remain': 1, 'reoriented': 1, 'reported': 1, 'represent': 1, 'representation': 2, 'represents': 1, 'reproduce': 1, 'require': 3, 'required': 1, 'requires': 2, 'research': 3, 'researchers': 1, 'resembles': 1, 'reserved': 1, 'resource': 3, 'resources': 1, 'respect': 1, 'response': 2, 'responses': 1, 'restricted': 1, 'result': 4, 'resulting': 1, 'results': 5, 'resurgence': 1, 'retain': 1, 'risk': 3, 'robotics': 2, 'robust': 1, 'robustness': 1, 'roger': 1, 'rosenblatt': 1, 'roughly': 1, 'routing': 1, 'rules': 4, 'run': 1, 'sample': 1, 'samples': 1, 'schemes': 1, 'schmidhuber': 2, 'science': 2, 'scientific': 1, 'search': 2, 'second': 2, 'secondary': 1, 'secondly': 1, 'security': 1, 'see': 1, 'seems': 2, 'select': 1, 'selected': 2, 'selecting': 2, 'self': 3, 'selflearning': 1, 'selfwires': 1, 'sensor': 3, 'sent': 1, 'separation': 1, 'seppo': 1, 'sequence': 2, 'sequential': 3, 'serial': 1, 'series': 1, 'serve': 1, 'set': 7, 'settlements': 1, 'several': 1, 'shallow': 2, 'shape': 1, 'shorten': 1, 'shortens': 1, 'shortterm': 4, 'showed': 1, 'shuffling': 1, 'sign': 1, 'signal': 9, 'signals': 4, 'significant': 1, 'significantly': 1, 'similar': 1, 'simple': 1, 'simpler': 1, 'simplest': 1, 'simplified': 1, 'simulate': 2, 'simulated': 2, 'simulating': 1, 'since': 1, 'single': 3, 'sir': 1, 'situation': 5, 'situations': 3, 'size': 4, 'slow': 1, 'small': 5, 'smooth': 1, 'socalled': 1, 'social': 2, 'softmax': 3, 'software': 1, 'solution': 2, 'solutions': 3, 'solve': 1, 'somethingfornothing': 1, 'sometimes': 1, 'soon': 1, 'source': 1, 'spam': 1, 'species': 1, 'specific': 3, 'speech': 4, 'speeding': 1, 'spite': 1, 'squared': 2, 'squares': 1, 'stable': 1, 'stagnated': 1, 'standard': 3, 'state': 4, 'states': 1, 'static': 1, 'statistic': 1, 'statistical': 7, 'statistically': 1, 'statistics': 2, 'stays': 1, 'step': 2, 'steps': 2, 'still': 1, 'stilwell': 1, 'stochastic': 4, 'stochastically': 1, 'storage': 1, 'stored': 1, 'straightforward': 1, 'strength': 2, 'stride': 1, 'string': 1, 'strongly': 1, 'structural': 1, 'structure': 1, 'stuck': 1, 'studied': 2, 'studies': 1, 'subject': 2, 'subsystems': 1, 'success': 1, 'successful': 3, 'successive': 1, 'sufficient': 1, 'sufficiently': 2, 'suited': 1, 'sum': 3, 'summarizes': 1, 'superturing': 1, 'supervised': 7, 'swarm': 1, 'symbolic': 1, 'synapses': 1, 'synthesis': 1, 'system': 5, 'systems': 13, 't1': 1, 'table': 2, 'tailored': 1, 'tails': 1, 'take': 1, 'taken': 1, 'takes': 3, 'talking': 1, 'target': 2, 'task': 6, 'tasks': 11, 'taskspecific': 1, 'teach': 1, 'teacher': 1, 'technically': 1, 'techniques': 2, 'technology': 3, 'tensor': 1, 'term': 1, 'testing': 1, 'text': 1, 'textstyle': 12, 'texttospeech': 1, 'theorem': 1, 'theoretical': 1, 'theory': 5, 'thereafter': 1, 'thereby': 1, 'therefore': 1, 'thirdly': 1, 'thomas': 1, 'thought': 1, 'threat': 1, 'three': 3, 'threshold': 3, 'thresholds': 1, 'thus': 2, 'time': 6, 'times': 2, 'together': 1, 'tolerance': 1, 'tool': 1, 'topology': 2, 'total': 1, 'toward': 1, 'towards': 1, 'tpu': 1, 'tradeoffs': 1, 'trading': 1, 'traditionally': 1, 'traffic': 1, 'trained': 1, 'training': 11, 'trajectory': 1, 'transformations': 1, 'transition': 2, 'transitions': 1, 'translation': 2, 'transmit': 2, 'travel': 1, 'traversing': 1, 'tries': 1, 'trivial': 1, 'true': 1, 'try': 1, 'trying': 1, 'tuning': 1, 'turing': 1, 'twentyfirst': 1, 'two': 7, 'twodimensional': 1, 'type': 3, 'types': 7, 'typically': 6, 'ultimate': 3, 'uncover': 1, 'uncovering': 1, 'understanding': 3, 'understood': 1, 'underway': 1, 'undesirable': 1, 'unfortunately': 1, 'unit': 2, 'units': 2, 'universal': 3, 'unknown': 1, 'unlabeled': 1, 'unlayered': 1, 'unpredictable': 1, 'unreadable': 2, 'unseen': 3, 'unsupervised': 6, 'update': 2, 'updates': 1, 'urls': 1, 'use': 12, 'used': 15, 'useful': 3, 'usefully': 1, 'uses': 3, 'using': 10, 'usually': 2, 'v': 2, 'vaguely': 1, 'valid': 1, 'validation': 1, 'value': 6, 'valueless': 1, 'values': 4, 'vanishing': 2, 'variables': 3, 'variance': 1, 'variety': 2, 'various': 3, 'varying': 1, 'vast': 1, 'vc': 5, 'vector': 2, 'vehicle': 2, 'verylargescale': 1, 'via': 4, 'video': 3, 'viewed': 1, 'vision': 1, 'visual': 2, 'visualization': 1, 'vlsi': 2, 'von': 1, 'vs': 2, 'w': 4, 'walter': 1, 'warren': 1, 'watching': 1, 'way': 3, 'weight': 8, 'weighted': 3, 'weightless': 1, 'weights': 11, 'well': 6, 'weng': 1, 'werbos': 1, 'wesley': 1, 'whereas': 1, 'whether': 1, 'whiskers': 1, 'whose': 3, 'wide': 1, 'widely': 1, 'width': 1, 'win': 1, 'winning': 2, 'within': 3, 'without': 5, 'work': 2, 'worked': 1, 'worth': 1, 'would': 4, 'writer': 1, 'writing': 1, 'x': 17, 'xf': 1, 'yields': 1, 'zero': 1, 'zoo': 1}, 'probability.txt': {'0p': 1, '13th': 1, '20th': 1, '2nd': 1, '8th': 1, 'ab': 1, 'ability': 1, 'abraham': 1, 'acap': 6, 'according': 2, 'accordingly': 1, 'account': 1, 'action': 2, 'actually': 1, 'actuarial': 1, 'acup': 3, 'addition': 1, 'adherents': 1, 'adlan': 1, 'adolphe': 1, 'adrain': 2, '
imperative': 1, 'implement': 2, 'implementation': 9, 'implementations': 8, 'implemented': 1, 'implements': 1, 'implicit': 2, 'import': 7, 'important': 2, 'improper': 1, 'improved': 1, 'improvement': 1, 'improvements': 1, 'improving': 1, 'include': 7, 'included': 1, 'includes': 5, 'including': 14, 'increase': 1, 'increases': 1, 'incremented': 4, 'indentation': 8, 'index': 6, 'indexes': 3, 'indicated': 1, 'indirectly': 1, 'industry': 1, 'infinity': 2, 'infix': 2, 'influenced': 3, 'informatica': 1, 'information': 4, 'infrequently—for': 1, 'inherit': 1, 'inherited': 1, 'initialization': 1, 'initially': 2, 'inkscape': 1, 'input': 1, 'inspired': 1, 'instagram': 1, 'installer': 2, 'installers': 1, 'instance': 4, 'instancemethod': 1, 'instances': 3, 'instead': 2, 'int': 1, 'integer': 8, 'integers': 2, 'integrate': 1, 'integrated': 1, 'integrates': 1, 'integration': 1, 'intelligence': 3, 'intended': 2, 'intends': 1, 'interactive': 1, 'interface': 3, 'interfaces': 3, 'interfacing': 1, 'intermediate': 1, 'internal': 1, 'internetfacing': 1, 'interpolation': 1, 'interpret': 1, 'interpreted': 1, 'interpreter': 8, 'interpreters': 1, 'interval': 2, 'intro': 1, 'introduce': 2, 'introduced': 4, 'involving': 1, 'ipython': 2, 'ironpython': 2, 'isbn': 6, 'issues': 3, 'ita': 1, 'item': 1, 'iterable': 2, 'iterate': 1, 'iterated': 1, 'iterates': 1, 'iteration': 1, 'iterators': 2, 'itertools': 1, 'j': 1, 'january': 3, 'java': 13, 'javascript': 2, 'jocelyn': 1, 'julia': 2, 'july': 3, 'justintime': 4, 'jython': 1, 'keeping': 1, 'kept': 1, 'keras': 1, 'key': 1, 'keys': 3, 'keywords': 2, 'kinds': 4, 'knowledgeable': 1, 'kotlin': 2, 'labs': 1, 'lambda': 2, 'language': 43, 'languages': 25, 'laptop': 1, 'large': 8, 'largely': 2, 'larger': 1, 'largescale': 1, 'last': 1, 'late': 3, 'later': 1, 'latest': 2, 'latter': 1, 'lazy': 1, 'lead': 2, 'leadership': 1, 'leads': 1, 'learn': 1, 'learning': 2, 'least': 1, 'left': 2, 'lefthand': 1, 'lego': 1, 'less': 2, 'lesscluttered': 1, 'levels': 1, 'libraries': 9, 'library': 11, 'libreoffice': 1, 'lie': 1, 'life': 1, 'lightwave': 1, 'like': 13, 'limited': 1, 'line': 2, 'lines': 1, 'links': 1, 'linux': 4, 'lisp': 2, 'list': 8, 'lists': 4, 'literal': 2, 'literals': 3, 'literature': 1, 'llvm': 2, 'local': 2, 'location': 2, 'lock': 3, 'logic': 1, 'logical': 1, 'long': 2, 'longterm': 1, 'loop': 2, 'lutz': 1, 'machine': 4, 'macos': 1, 'macros': 2, 'made': 2, 'magic': 1, 'mailing': 1, 'main': 1, 'maintaining': 1, 'maintains': 1, 'maintenance': 1, 'major': 8, 'make': 1, 'makes': 2, 'management': 2, 'manager': 2, 'manages': 1, 'manipulating': 1, 'manipulation': 2, 'manner': 2, 'manually': 1, 'many': 17, 'map': 1, 'mapper': 1, 'march': 1,
entheses': 1, 'part': 7, 'partially': 1, 'particular': 1, 'particularly': 2, 'parts': 2, 'pascal': 1, 'pass': 2, 'passed': 2, 'patched': 1, 'patches': 2, 'paths': 1, 'pep': 5, 'peps': 1, 'per': 1, 'performance': 2, 'performed': 1, 'perl': 4, 'perlinfluenced': 1, 'permanent': 1, 'permitting': 1, 'peter': 1, 'philosophy': 7, 'phones': 1, 'pi': 1, 'pilgrim': 2, 'pip': 1, 'place': 1, 'plan': 1, 'planned': 1, 'platform': 2, 'platforms': 1, 'playful': 1, 'point': 2, 'pointdivision': 1, 'popular': 3, 'portability': 1, 'portage': 1, 'ported': 1, 'positive': 4, 'possible': 2, 'postponed': 1, 'potentially': 1, 'powerful': 2, 'practice': 1, 'practices': 1, 'precedence': 1, 'precision': 2, 'predefined': 1, 'preferably': 1, 'prefix': 2, 'prefixing': 1, 'premature': 1, 'prentice': 1, 'presented': 1, 'pretty': 1, 'previews': 1, 'primary': 2, 'print': 2, 'printer': 1, 'printf': 1, 'priorities': 1, 'pro': 1, 'probably': 1, 'problems': 2, 'procedural': 1, 'procedures': 1, 'process': 1, 'processing': 5, 'produce': 1, 'produced': 1, 'produces': 3, 'productive': 1, 'products': 1, 'professional': 1, 'program': 9, 'programmable': 2, 'programmer': 1, 'programmers': 3, 'programmes': 1, 'programming': 31, 'programminglanguage': 1, 'programs': 7, 'project': 6, 'projects': 2, 'promotes': 1, 'property': 1, 'proposal': 1, 'proposing': 1, 'protocols': 1, 'provided': 4, 'provider': 1, 'provides': 4, 'providing': 1, 'pseudorandom': 1, 'psyco': 1, 'public': 1, 'punctuation': 1, 'put': 1, 'py': 1, 'pyaiml': 1, 'pycalljl': 1, 'pycon': 1, 'pydoc': 1, 'pygame': 1, 'pygtk': 1, 'pyjs': 2, 'pyjulia': 1, 'pyladies': 1, 'pylons': 1, 'pypi': 1, 'pypipythonorg': 1, 'pypy': 5, 'pyqt': 1, 'pyramid': 1, 'pyrex': 1, 'pys60': 1, 'python': 205, 'pythonanywhere': 1, 'pythondev': 1, 'pythonic': 2, 'pythoninspired': 2, 'pythonistas': 1, 'python—and': 1, 'pythran': 1, 'pytorch': 1, 'qt': 1, 'quite': 1, 'quote': 4, 'quoting': 1, 'r': 1, 'raii': 1, 'raise': 2, 'raised': 1, 'range': 2, 'ranked': 1, 'raspberry': 1, 'rather': 6, 'rational': 1, 'rationale': 1, 'raw': 2, 'readability': 3, 'readable': 1, 'reading': 1, 'reads': 1, 'ready': 1, 'read–eval–print': 1, 'rebound': 1, 'receives': 3, 'red': 1, 'reddit': 1, 'reduce': 1, 'refer': 1, 'reference': 12, 'references': 3, 'referred': 1, 'reflect': 1, 'reflected': 1, 'reflection': 1, 'regardless': 1, 'regular': 2, 'reject': 1, 'related': 2, 'relational': 2, 'relations': 1, 'relative': 1, 'release': 7, 'releasecandidates': 1, 'released': 10, 'releases': 7, 'releasing': 1, 'remainder': 2, 'repl': 1, 'replace': 1, 'replaces': 1, 'repository': 2, 'represent': 1, 'represents': 1, 'requiring': 1, 'rera
2, 'suffer': 1, 'sufficient': 1, 'sugar': 3, 'suitable': 1, 'suite': 1, 'suited': 1, 'suites': 1, 'summarized': 1, 'summerfield': 1, 'supplemented': 1, 'support': 7, 'supported': 5, 'supports': 4, 'surrounding': 1, 'swallow': 1, 'swift': 1, 'symbian': 1, 'symbolic': 2, 'symbols': 1, 'syntactic': 2, 'syntactically': 2, 'syntax': 16, 'system': 6, 'systems': 3, 'tail': 1, 'take': 1, 'target': 1, 'tasks': 1, 'tcl': 1, 'team': 1, 'ten': 1, 'tensorflow': 1, 'term': 1, 'termed': 4, 'terminal': 1, 'terms': 1, 'test': 3, 'testing': 2, 'tests': 2, 'text': 2, 'theories': 1, 'theory': 1, 'thereby': 1, 'think': 2, 'third': 3, 'thirdparty': 3, 'though': 1, 'thousands': 1, 'three': 6, 'thus': 5, 'tiebreaking': 1, 'time': 4, 'timecritical': 1, 'tiobe': 1, 'title': 1, 'token': 1, 'took': 1, 'tools': 3, 'top': 1, 'tornado': 1, 'towards': 3, 'tracker': 1, 'tradition': 1, 'traditional': 3, 'transcription': 1, 'transforms': 1, 'translates': 3, 'translation': 1, 'tribute': 1, 'triplequoted': 1, 'true': 4, 'try': 1, 'tryfinally': 1, 'tuple': 4, 'tuples': 5, 'turbogears': 1, 'tutorials': 1, 'twisted': 1, 'two': 5, 'type': 11, 'typeclass': 1, 'typed': 8, 'types': 6, 'typing': 6, 'ubiquity': 1, 'ubuntu': 1, 'ugly': 1, 'unambiguous': 1, 'unary': 1, 'uncluttered': 1, 'understand': 1, 'unicode': 1, 'unidirectionally': 1, 'unintended': 1, 'unit': 3, 'unix': 1, 'unixlike': 1, 'unladen': 1, 'unlike': 2, 'unmodified': 1, 'unpacking': 1, 'unpythonic': 1, 'unreasonable': 1, 'unrestricted': 1, 'unsupported': 2, 'untyped': 1, 'upon': 1, 'upper': 1, 'upstream': 1, 'uptodate': 1, 'usable': 1, 'use': 17, 'used': 32, 'useful': 1, 'user': 3, 'userfriendly': 1, 'userprogramming': 1, 'users': 1, 'uses': 16, 'using': 6, 'usual': 1, 'utility': 1, 'vacation': 1, 'valid': 2, 'validity': 1, 'value': 9, 'values': 4, 'van': 7, 'variable': 9, 'variables': 4, 'variant': 1, 'variants': 2, 'varieties': 1, 'various': 3, 'varying': 1, 'version': 13, 'versions': 3, 'versus': 1, 'vhdl': 1, 'via': 2, 'video': 1, 'videogames': 1, 'virtual': 1, 'vision': 1, 'visual': 2, 'visually': 1, 'vs': 3, 'vulnerabilities': 1, 'walrus': 1, 'wanted': 1, 'warsaw': 1, 'way': 2, 'ways': 1, 'web': 8, 'web2py': 1, 'website': 1, 'well': 2, 'welldefined': 1, 'wherein': 1, 'whether': 2, 'whitespace': 2, 'whole': 1, 'whose': 1, 'wide': 2, 'widget': 1, 'wikipedia': 1, 'wikipythonorg': 1, 'willing': 1, 'windows': 1, 'windowsstyle': 1, 'wiskunde': 1, 'within': 1, 'words': 1, 'work': 1, 'working': 1, 'workload': 1, 'world': 1, 'worse': 1, 'would': 3, 'writable': 2, 'write': 1, 'writes': 1, 'writing': 1, 'written': 12, 'wsgi': 1, 'wsgiref': 1, 'x': 7, 'xo': 1, 'yahoo': 1, 'year': 1, 'yearly': 1, 'years': 2, 'yield': 2, 'yields': 1, 'yukihiro': 1, 'z': 1, 'zen': 1, 'zerobased': 1, 'zope': 1, '−10python': 1}}

# %%
print (list(mydic).count('analysis'))
# Out:
# 0

# %%
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']
print (fruits[:2])
# Out:
# ['orange', 'apple']

# %%
dtfidfs={'artificial_intelligence.txt': 2.7566117677166404, 'machine_learning.txt': 7.216727956906449, 'natural_language_processing.txt': 0.7701082216960735, 'neural_network.txt': 4.114506654314832, 'probability.txt': 0.0, 'python.txt': 1.0939293407637276}

# %%
print (dict (sorted (dtfidfs.items(), key=lambda item: item[1], reverse=True)))
# Out:
# {'machine_learning.txt': 7.216727956906449, 'neural_network.txt': 4.114506654314832, 'artificial_intelligence.txt': 2.7566117677166404, 'python.txt': 1.0939293407637276, 'natural_language_processing.txt': 0.7701082216960735, 'probability.txt': 0.0}

# %%
dtfidfs = (dict (sorted (dtfidfs.items(), key=lambda item: item[1], reverse=True)))

# %%
n = 2
result = list(dtfidfs.keys())[:n]
result
# Out:
# ['machine_learning.txt', 'neural_network.txt']

# %%
sentence_idf = {'https://en.wikipedia.org/wiki/Machine_learning': [0, 0, 2], 'Machine learning (ML) is the study of computer algorithms that improve automatically through experience.': [0.8706610357857967, 1, 9], 'It is seen as a subset of artificial intelligence.': [0, 0, 4], 'Machine learning algorithms build a mathematical model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to do so.': [0.8706610357857967, 1, 19], 'Machine learning algorithms are used in a wide variety of applications, such as email filtering and computer vision, where it is difficult or infeasible to develop  conventional algorithms to perform the needed tasks.': [0.8706610357857967, 1, 19], 'Machine learning is closely related to computational statistics, which focuses on making predictions using computers.': [0.8706610357857967, 1, 11], 'The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning.': [0.8706610357857967, 1, 11], 'Data mining is a related field of study, focusing on exploratory data analysis through unsupervised learning.': [0.8706610357857967, 1, 11], 'In its application across business problems, machine learning is also referred to as predictive analytics.': [0.8706610357857967, 1, 10], '== Overview ==': [0, 0, 1], 'Machine learning involves computers discovering how they can perform tasks without being explicitly programmed to do so.': [0.8706610357857967, 1, 10], 'For early tasks that humans assigned to computers, it was possible to create algorithms telling the machine how to execute all needed steps to solve the problem in hand.': [0, 0, 16], "So on the computer's part, no learning was needed.": [0.8706610357857967, 1, 4], 'For more advanced tasks, it can be challenging for a human to manually create the needed algorithms.': [0, 0, 8], 'In practice, it can turn out to be more effective to help the machine develop its own algorithm, rather than have human programmers specify every needed step.': [0, 0, 14], 'The discipline of machine learning employs various approaches to help computers learn to accomplish tasks for which no fully satisfactory algorithm exists.': [0.8706610357857967, 1, 15], 'For example, for cases where vast numbers of potential answers exist, some of the correct ones can be labelled as valid, and this can be used as training data for the computer to improve the algorithm(s) it uses to determine correct answers.': [0, 0, 21], '=== Machine learning approaches ===': [0.8706610357857967, 1, 3], 'Early classifications for machine learning approaches sometimes divided them into three broad categories, depending on the nature of the "signal" or "feedback" available to the learning system.': [1.7413220715715934, 2, 17], 'Supervised learning:  The computer is presented with example inputs and their desired outputs, given by a "teacher", and the goal is to learn a general rule that maps inputs to outputs.': [3.9677458036000752, 2, 17], 'Unsupervised learning:  No labels are given to the learning algorithm, leaving it on its own to find structure in its input.': [1.7413220715715934, 2, 10], 'Unsupervised learning can be a goal in itself (discovering hidden patterns in data) or a means towards an end (feature learning).': [1.7413220715715934, 2, 12], "Reinforcement learning:  A computer program interacts with a dynamic environment in which it must perform a certain goal (such as driving a vehicle or playing a game against an opponent) As it navigates its problem space, the program is provided feedback that's analogous to rewards, which it tries to maximise.": [0.8706610357857967, 1, 26], "Other approaches or processes have since developed that don't fit neatly into this three-fold categorisation, and sometimes more than one is used by the same machine learning system.": [0.8706610357857967, 1, 15], 'For example topic modeling, dimensionality reduction or meta learning.': [0.8706610357857967, 1, 7], 'As of 2020, deep learning had become the dominant approach for much ongoing work in the field of machine learning .': [1.7413220715715934, 2, 11], '== History and relationships to other fields ==': [0, 0, 3], 'The term machine learning was coined in 1959 by Arthur Samuel, an American IBMer and pioneer in the field of computer gaming and artificial intelligence.': [0.8706610357857967, 1, 14], "A representative book of the machine learning research during the 1960s was the Nilsson's book on Learning Machines, dealing mostly with machine learning for pattern classification.": [2.61198310735739, 3, 16], 'Interest related to pattern recognition continued into the 1970s, as described by Duda and Hart in 1973.': [0, 0, 9], 'In 1981 a report was given on using teaching strategies so that a neural network learns to recognize 40 characters (26 letters, 10 digits, and 4 special symbols) from a computer terminal.': [0, 0, 16], 'Tom M. Mitchell provided a widely quoted, more formal definition of the algorithms studied in the machine learning field: "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P,  improves with experience E." This definition of the tasks in which machine learning is concerned offers a fundamentally operational definition rather than defining the field in cognitive terms.': [1.7413220715715934, 2, 45], 'This follows Alan Turing\'s proposal in his paper "Computing Machinery and Intelligence", in which the question "Can machines think?"': [0, 0, 11], 'is replaced with the question "Can machines do what we (as thinking entities) can do?': [0, 0, 5], '=== Relation to artificial intelligence ===': [0, 0, 3], 'As a scientific endeavor, machine learning grew out of the quest for artificial intelligence.': [0.8706610357857967, 1, 8], 'In the early days of AI as an academic discipline, some researchers were interested in having machines learn from data.': [0, 0, 10], 'They attempted to approach the problem with various symbolic methods, as well as what were then termed "neural networks"; these were mostly perceptrons and other models that were later found to be reinventions of the generalized linear models of statistics.': [0, 0, 20], 'Probabilistic reasoning was also employed, especially in automated medical diagnosis.': [0, 0, 8], 'However, an increasing emphasis on the logical, knowledge-based approach caused a rift between AI and machine learning.': [0.8706610357857967, 1, 11], 'Probabilistic systems were plagued by theoretical and practical problems of data acquisition and representation.': [0, 0, 9], 'By 1980, expert systems had come to dominate AI, and statistics was out of favor.': [0, 0, 7], 'Work on symbolic/knowledge-based learning did continue within AI, leading to inductive logic programming, but the more statistical line of research was now outside the field of AI proper, in pattern recognition and information retrieval.': [0.8706610357857967, 1, 21], 'Neural networks research had been abandoned by AI and computer science around the same time.': [0, 0, 9], 'This line, too, was continued outside the AI/CS field, as "connectionism", by researchers from other disciplines including Hopfield, Rumelhart and Hinton.': [0, 0, 12], 'Their main success came in the mid-1980s with the reinvention of backpropagation.': [0, 0, 6], 'Machine learning, reorganized as a separate field, started to flourish in the 1990s.': [0.8706610357857967, 1, 8], 'The field changed its goal from achieving artificial intelligence to tackling solvable problems of a practical nature.': [0, 0, 11], 'It shifted focus away from the symbolic approaches it had inherited from AI, and toward methods and models borrowed from statistics and probability theory.': [0, 0, 14], 'As of 2019, many sources continue to assert that machine learning remains a sub field of AI.': [0.8706610357857967, 1, 10], 'Yet some practitioners, for example Dr Daniel Hulme, who both teaches AI and  runs a company operating in the field, argues that machine learning and AI are separate.': [0.8706610357857967, 1, 17], '=== Relation to data mining ===': [0, 0, 3], 'Machine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases).': [1.7413220715715934, 2, 32], 'Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy.': [2.61198310735739, 3, 24], 'Much of the confusion between these two research communities (which do often have separate conferences and separate journals, ECML PKDD being a major exception) comes from the basic assumptions they work with: in machine learning, performance is usually evaluated with respect to the ability to reproduce known knowledge, while in knowledge discovery and data mining (KDD) the key task is the discovery of previously unknown knowledge.': [0.8706610357857967, 1, 39], 'Evaluated with respect to known knowledge, an uninformed (unsupervised) method will easily be outperformed by other supervised methods, while in a typical KDD task, supervised methods cannot be used due to the unavailability of training data.': [6.194169535628557, 2, 21], '=== Relation to optimization ===': [0, 0, 2], 'Machine learning also has intimate ties to optimization: many learning problems are formulated as minimization of some loss function on a training set of examples.': [1.7413220715715934, 2, 16], 'Loss functions express the discrepancy between the predictions of the model being trained and the actual problem instances (for example, in classification, one wants to assign a label to instances, and models are trained to correctly predict the pre-assigned labels of a set of examples).': [0, 0, 25], 'The difference between the two fields arises from the goal of generalization: while optimization algorithms can minimize the loss on a training set, machine learning is concerned with minimizing the loss on unseen samples.': [0.8706610357857967, 1, 19], '=== Relation to statistics ===': [0, 0, 2], 'Machine learning and statistics are closely related fields in terms of methods, but distinct in their principal goal: statistics draws population inferences from a sample, while machine learning finds generalizable predictive patterns.': [1.7413220715715934, 2, 22], 'According to Michael I. Jordan, the ideas of machine learning, from methodological principles to theoretical tools, have had a long pre-history in statistics.': [0.8706610357857967, 1, 13], 'He also suggested the term data science as a placeholder to call the overall field.': [0, 0, 9], 'Leo Breiman distinguished two statistical modeling paradigms: data model and algorithmic model, wherein "algorithmic model" means more or less the machine learning algorithms like Random forest.': [0.8706610357857967, 1, 22], 'Some statisticians have adopted methods from machine learning, leading to a combined field that they call statistical learning.': [1.7413220715715934, 2, 11], '== Theory ==': [0, 0, 1], 'A core objective of a learner is to generalize from its experience.': [0, 0, 5], 'Generalization in this context is the ability of a learning machine to perform accurately on new, unseen examples/tasks after having experienced a learning data set.': [1.7413220715715934, 2, 14], 'The training examples come from some generally unknown probability distribution (considered representative of the space of occurrences) and the learner has to build a general model about this space that enables it to produce sufficiently accurate predictions in new cases.': [0, 0, 23], 'The computational analysis of machine learning algorithms and their performance is a branch of theoretical computer science known as computational learning theory.': [1.7413220715715934, 2, 14], 'Because training sets are finite and the future is uncertain, learning theory usually does not yield guarantees of the performance of algorithms.': [0.8706610357857967, 1, 12], 'Instead, probabilistic bounds on the performance are quite common.': [0, 0, 6], 'The bias–variance decomposition is one way to quantify generalization error.': [0, 0, 7], 'For the best performance in the context of generalization, the complexity of the hypothesis should match the complexity of the function underlying the data.': [0, 0, 11], 'If the hypothesis is less complex than the function, then the model has under fitted the data.': [0, 0, 7], 'If the complexity of the model is increased in response, then the training error decreases.': [0, 0, 7], 'But if the hypothesis is too complex, then the model is subject to overfitting and generalization will be poorer.': [0, 0, 7], 'In addition to performance bounds, learning theorists study the time complexity and feasibility of learning.': [1.7413220715715934, 2, 10], 'In computational learning theory, a computation is considered feasible if it can be done in polynomial time.': [0.8706610357857967, 1, 9], 'There are two kinds of time complexity results.': [0, 0, 5], 'Positive results show that a certain class of functions can be learned in polynomial time.': [0, 0, 9], 'Negative results show that certain classes cannot be learned in polynomial time.': [0, 0, 8], '== Approaches ==': [0, 0, 1], '=== Types of learning algorithms ===': [5.289501643582395, 2, 3], 'The types of machine learning algorithms differ in their approach, the type of data they input and output, and the type of task or problem that they are intended to solve.': [5.289501643582395, 2, 15], '==== Supervised learning ====': [3.9677458036000752, 2, 2], 'Supervised learning algorithms build a mathematical model of a set of data that contains both the inputs and the desired outputs.': [3.9677458036000752, 2, 12], 'The data is known as training data, and consists of a set of training examples.': [0, 0, 8], 'Each training example has one or more inputs and the desired output, also known as a supervisory signal.': [0, 0, 10], 'In the mathematical model, each training example is represented by an array or vector, sometimes called a feature vector, and the training data is represented by a matrix.': [0, 0, 15], 'Through iterative optimization of an objective function, supervised learning algorithms learn a function that can be used to predict the output associated with new inputs.': [3.9677458036000752, 2, 15], 'An optimal function will allow the algorithm to correctly determine the output for inputs that were not a part of the training data.': [0, 0, 11], 'An algorithm that improves the accuracy of its outputs or predictions over time is said to have learned to perform that task.': [0, 0, 10], 'Types of supervised learning algorithms include Active learning , classification and regression.': [9.25724744718247, 4, 9], 'Classification algorithms are used when the outputs are restricted to a limited set of values, and regression algorithms are used when the outputs may have any numerical value within a range.': [0, 0, 17], 'As an example, for a classification algorithm that filters emails, the input would be an incoming email, and the output would be the name of the folder in which to file the email.': [0, 0, 15], 'Similarity learning is an area of supervised machine learning closely related to regression and classification, but the goal is to learn from examples using a similarity function that measures how similar or related two objects are.': [4.838406839385872, 3, 21], 'It has applications in ranking, recommendation systems, visual identity tracking, face verification, and speaker verification.': [0, 0, 11], '==== Unsupervised learning ====': [0.8706610357857967, 1, 2], 'Unsupervised learning algorithms take a set of data that contains only inputs, and find structure in the data, like grouping or clustering of data points.': [0.8706610357857967, 1, 16], 'The algorithms, therefore, learn from test data that has not been labeled, classified or categorized.': [0, 0, 8], 'Instead of responding to feedback, unsupervised learning algorithms identify commonalities in the data and react based on the presence or absence of such commonalities in each new piece of data.': [0.8706610357857967, 1, 17], 'A central application of unsupervised learning is in the field of density estimation in statistics, such as finding the probability density function.': [0.8706610357857967, 1, 12], 'Though unsupervised learning encompasses other domains involving summarizing and explaining data features.': [0.8706610357857967, 1, 10], 'Cluster analysis is the assignment of a set of observations into subsets (called clusters) so that observations within the same cluster are similar according to one or more predesignated criteria, while observations drawn from different clusters are dissimilar.': [0, 0, 21], 'Different clustering techniques make different assumptions on the structure of the data, often defined by some similarity metric and evaluated, for example, by internal compactness, or the similarity between members of the same cluster, and separation, the difference between clusters.': [0, 0, 22], 'Other methods are based on estimated density and graph connectivity.': [0, 0, 6], '==== Semi-supervised learning ====': [0.8706610357857967, 1, 2], 'Semi-supervised learning falls between unsupervised learning (without any labeled training data) and supervised learning (with completely labeled training data).': [5.709067875171669, 4, 15], 'Some of the training examples are missing training labels,  yet many machine-learning researchers have found that unlabeled data, when used in conjunction with a small amount of labeled data, can produce a considerable improvement in learning accuracy.': [0.8706610357857967, 1, 23], 'In weakly supervised learning, the training labels are noisy, limited, or imprecise; however, these labels are often cheaper to obtain, resulting in larger effective training sets.': [3.9677458036000752, 2, 18], '==== Reinforcement learning ====': [0.8706610357857967, 1, 2], 'Reinforcement learning is an area of machine learning concerned with how software agents ought to take actions in an environment so as to maximize some notion of cumulative reward.': [1.7413220715715934, 2, 16], 'Due to its generality, the field is studied in many other disciplines, such as game theory, control theory, operations research, information theory, simulation-based optimization, multi-agent systems, swarm intelligence, statistics and genetic algorithms.': [0, 0, 23], 'In machine learning, the environment is typically represented as a Markov Decision Process (MDP).': [0.8706610357857967, 1, 9], 'Many reinforcement learning algorithms use dynamic programming techniques.': [0.8706610357857967, 1, 8], 'Reinforcement learning algorithms do not assume knowledge of an exact mathematical model of the MDP, and are used when exact models are infeasible.': [0.8706610357857967, 1, 13], 'Reinforcement learning algorithms are used in autonomous vehicles or in learning to play a game against a human opponent.': [1.7413220715715934, 2, 11], '==== Self learning ====': [0.8706610357857967, 1, 2], 'Self-learning as machine learning paradigm was introduced in 1982 along with a neural network capable of self-learning  named Crossbar Adaptive Array (CAA).': [0.8706610357857967, 1, 15], 'It is a learning with no external rewards and no external teacher advices.': [0.8706610357857967, 1, 6], 'The CAA self-learning algorithm computes, in a crossbar fashion, both decisions about actions and emotions (feelings) about consequence situations.': [0, 0, 12], 'The system is driven by the interaction between cognition and emotion.': [0, 0, 5], 'The self-learning algorithm updates a memory matrix W =||w(a,s)|| such that in each iteration executes the following machine learning  routine:': [0.8706610357857967, 1, 13], ' In situation s perform action a;': [0, 0, 3], ' Receive consequence situation s’;': [0, 0, 3], ' Compute emotion of being in consequence situation v(s’);': [0, 0, 5], ' Update crossbar memory  w’(a,s) = w(a,s) + v(s’).': [0, 0, 6], 'It is a system with only one input, situation s, and only one output, action (or behavior) a.': [0, 0, 8], 'There is neither a separate reinforcement input nor an advice input from the environment.': [0, 0, 7], 'The backpropagated value (secondary reinforcement) is the emotion toward the consequence situation.': [0, 0, 8], 'The CAA exists in two environments, one is behavioral environment where it behaves, and the other is genetic environment, wherefrom it initially and only once receives initial emotions about situations to be encountered in the  behavioral environment.': [0, 0, 19], 'After receiving the genome (species) vector from the genetic environment, the CAA learns a goal seeking behavior, in an environment that contains both desirable and undesirable situations.': [0, 0, 16], '==== Feature learning ====': [0.8706610357857967, 1, 2], 'Several learning algorithms aim at discovering better representations of the inputs provided during training.': [0.8706610357857967, 1, 10], 'Classic examples include principal components analysis and cluster analysis.': [0, 0, 8], 'Feature learning algorithms, also called representation learning algorithms, often attempt to preserve the information in their input but also transform it in a way that makes it useful, often as a pre-processing step before performing classification or predictions.': [1.7413220715715934, 2, 24], 'This technique allows reconstruction of the inputs coming from the unknown data-generating distribution, while not being necessarily faithful to configurations that are implausible under that distribution.': [0, 0, 13], 'This replaces manual feature engineering, and allows a machine to both learn the features and use them to perform a specific task.': [0, 0, 12], 'Feature learning can be either supervised or unsupervised.': [3.9677458036000752, 2, 5], 'In supervised feature learning, features are learned using labeled input data.': [3.9677458036000752, 2, 9], 'Examples include artificial neural networks, multilayer perceptrons, and supervised dictionary learning.': [3.9677458036000752, 2, 10], 'In unsupervised feature learning, features are learned with unlabeled input data.': [0.8706610357857967, 1, 8], 'Examples include dictionary learning, independent component analysis, autoencoders, matrix factorization and various forms of clustering.': [0.8706610357857967, 1, 13], 'Manifold learning algorithms attempt to do so under the constraint that the learned representation is low-dimensional.': [0.8706610357857967, 1, 8], 'Sparse coding algorithms attempt to do so under the constraint that the learned representation is sparse, meaning that the mathematical model has many zeros.': [0, 0, 13], 'Multilinear subspace learning algorithms aim to learn low-dimensional representations directly from tensor representations for multidimensional data, without reshaping them into higher-dimensional vectors.': [0.8706610357857967, 1, 17], 'Deep learning algorithms discover multiple levels of representation, or a hierarchy of features, with higher-level, more abstract features defined in terms of (or generating) lower-level features.': [0.8706610357857967, 1, 17], 'It has been argued that an intelligent machine is one that learns a representation that disentangles the underlying factors of variation that explain the observed data.': [0, 0, 13], 'Feature learning is motivated by the fact that machine learning tasks such as classification often require input that is mathematically and computationally convenient to process.': [1.7413220715715934, 2, 15], 'However, real-world data such as images, video, and sensory data has not yielded to attempts to algorithmically define specific features.': [0, 0, 13], 'An alternative is to discover such features or representations through examination, without relying on explicit algorithms.': [0, 0, 9], '==== Sparse dictionary learning ====': [0.8706610357857967, 1, 3], 'Sparse dictionary learning is a feature learning method where a training example is represented as a linear combination of basis functions, and is assumed to be a sparse matrix.': [1.7413220715715934, 2, 16], 'The method is strongly NP-hard and difficult to solve approximately.': [0, 0, 6], 'A popular heuristic method for sparse dictionary learning is the K-SVD algorithm.': [0.8706610357857967, 1, 8], 'Sparse dictionary learning has been applied in several contexts.': [0.8706610357857967, 1, 6], 'In classification, the problem is to determine the class to which a previously unseen training example belongs.': [0, 0, 9], 'For a dictionary where each class has already been built, a new training example is associated with the class that is best sparsely represented by the corresponding dictionary.': [0, 0, 14], 'Sparse dictionary learning has also been applied in image de-noising.': [0.8706610357857967, 1, 7], 'The key idea is that a clean image patch can be sparsely represented by an image dictionary, but the noise cannot.': [0, 0, 10], '==== Anomaly detection ====': [0, 0, 2], 'In data mining, anomaly detection, also known as outlier detection, is the identification of rare items, events or observations which raise suspicions by differing significantly from the majority of the data.': [0, 0, 19], 'Typically, the anomalous items represent an issue such as bank fraud, a structural defect, medical problems or errors in a text.': [0, 0, 13], 'Anomalies are referred to as outliers, novelties, noise, deviations and exceptions.': [0, 0, 7], 'In particular, in the context of abuse and network intrusion detection, the interesting objects are often not rare objects, but unexpected bursts in activity.': [0, 0, 14], 'This pattern does not adhere to the common statistical definition of an outlier as a rare object, and many outlier detection methods (in particular, unsupervised algorithms) will fail on such data, unless it has been aggregated appropriately.': [0, 0, 20], 'Instead, a cluster analysis algorithm may be able to detect the micro-clusters formed by these patterns.': [0, 0, 10], 'Three broad categories of anomaly detection techniques exist.': [0, 0, 7], 'Unsupervised anomaly detection techniques detect anomalies in an unlabeled test data set under the assumption that the majority of the instances in the data set are normal, by looking for instances that seem to fit least to the remainder of the data set.': [0, 0, 24], 'Supervised anomaly detection techniques require a data set that has been labeled as "normal" and "abnormal" and involves training a classifier (the key difference to many other statistical classification problems is the inherently unbalanced nature of outlier detection).': [3.0970847678142785, 1, 24], 'Semi-supervised anomaly detection techniques construct a model representing normal behavior from a given normal training data set and then test the likelihood of a test instance to be generated by the model.': [0, 0, 20], '==== Robot learning ====': [0.8706610357857967, 1, 2], 'In developmental robotics, robot learning algorithms generate their own sequences of learning experiences, also known as a curriculum, to cumulatively acquire new skills through self-guided exploration and social interaction with humans.': [1.7413220715715934, 2, 21], 'These robots use guidance mechanisms such as active learning, maturation, motor synergies and imitation.': [0.8706610357857967, 1, 10], '==== Association rules ====': [0, 0, 2], 'Association rule learning is a rule-based machine learning method for discovering relationships between variables in large databases.': [1.7413220715715934, 2, 12], 'It is intended to identify strong rules discovered in databases using some measure of "interestingness".Rule-based machine learning is a general term for any machine learning method that identifies, learns, or evolves "rules" to store, manipulate or apply knowledge.': [1.7413220715715934, 2, 25], 'The defining characteristic of a rule-based machine learning algorithm is the identification and utilization of a set of relational rules that collectively represent the knowledge captured by the system.': [0.8706610357857967, 1, 16], 'This is in contrast to other machine learning algorithms that commonly identify a singular model that can be universally applied to any instance in order to make a prediction.': [0.8706610357857967, 1, 14], 'Rule-based machine learning approaches include learning classifier systems, association rule learning, and artificial immune systems.': [2.61198310735739, 3, 14], 'Based on the concept of strong rules, Rakesh Agrawal, Tomasz Imieliński and Arun Swami introduced association rules for discovering regularities between products in large-scale transaction data recorded by point-of-sale (POS) systems in supermarkets.': [0, 0, 24], 'For example, the rule': [0, 0, 2], '          n': [0, 0, 1], '          p': [0, 0, 1], '          e': [0, 0, 1], '          b': [0, 0, 1], '          u': [0, 0, 1], '          r': [0, 0, 1], '          g': [0, 0, 1], '    {\\displaystyle \\{\\mathrm {onions,potatoes} \\}\\Rightarrow \\{\\mathrm {burger} \\}}': [0, 0, 7], '   found in the sales data of a supermarket would indicate that if a customer buys onions and potatoes together, they are likely to also buy hamburger meat.': [0, 0, 16], 'Such information can be used as the basis for decisions about marketing activities such as promotional pricing or product placements.': [0, 0, 10], 'In addition to market basket analysis, association rules are employed today in application areas including Web usage mining, intrusion detection, continuous production, and bioinformatics.': [0, 0, 19], 'In contrast with sequence mining, association rule learning typically does not consider the order of items either within a transaction or across transactions.': [0.8706610357857967, 1, 15], 'Learning classifier systems (LCS) are a family of rule-based machine learning algorithms that combine a discovery component, typically a genetic algorithm, with a learning component, performing either supervised learning, reinforcement learning, or unsupervised learning.': [8.321050982529059, 7, 25], 'They seek to identify a set of context-dependent rules that collectively store and apply knowledge in a piecewise manner in order to make predictions.': [0, 0, 14], 'Inductive logic programming (ILP) is an approach to rule-learning using logic programming as a uniform representation for input examples, background knowledge, and hypotheses.': [0, 0, 16], 'Given an encoding of the known background knowledge and a set of examples represented as a logical database of facts, an ILP system will derive a hypothesized logic program that entails all positive and no negative examples.': [0, 0, 21], 'Inductive programming is a related field that considers any kind of programming languages for representing hypotheses (and not only logic programming), such as functional programs.': [0, 0, 14], 'Inductive logic programming is particularly useful in bioinformatics and natural language processing.': [0, 0, 9], 'Gordon Plotkin and Ehud Shapiro laid the initial theoretical foundation for inductive machine learning in a logical setting.': [0.8706610357857967, 1, 13], 'Shapiro built their first implementation (Model Inference System) in 1981: a Prolog program that inductively inferred logic programs from positive and negative examples.': [0, 0, 16], 'The term inductive here refers to philosophical induction, suggesting a theory to explain observed facts, rather than mathematical induction, proving a property for all members of a well-ordered set.': [0, 0, 18], '=== Models ===': [0, 0, 1], 'Performing machine learning involves creating a model, which is trained on some training data and then can process additional data to make predictions.': [0.8706610357857967, 1, 14], 'Various types of models have been used and researched for machine learning systems.': [5.289501643582395, 2, 8], '==== Artificial neural networks ====': [0, 0, 3], 'Artificial neural networks (ANNs), or connectionist systems, are computing systems vaguely inspired by the biological neural networks that constitute animal brains.': [0, 0, 16], 'Such systems "learn" to perform tasks by considering examples, generally without being programmed with any task-specific rules.': [0, 0, 11], 'An ANN is a model based on a collection of connected units or nodes called "artificial neurons", which loosely model the neurons in a biological brain.': [0, 0, 15], 'Each connection, like the synapses in a biological brain, can transmit information, a "signal", from one artificial neuron to another.': [0, 0, 12], 'An artificial neuron that receives a signal can process it and then signal additional artificial neurons connected to it.': [0, 0, 10], 'In common ANN implementations, the signal at a connection between artificial neurons is a real number, and the output of each artificial neuron is computed by some non-linear function of the sum of its inputs.': [0, 0, 17], 'The connections between artificial neurons are called "edges".': [0, 0, 5], 'Artificial neurons and edges typically have a weight that adjusts as learning proceeds.': [0.8706610357857967, 1, 8], 'The weight increases or decreases the strength of the signal at a connection.': [0, 0, 6], 'Artificial neurons may have a threshold such that the signal is only sent if the aggregate signal crosses that threshold.': [0, 0, 10], 'Typically, artificial neurons are aggregated into layers.': [0, 0, 5], 'Different layers may perform different kinds of transformations on their inputs.': [0, 0, 8], 'Signals travel from the first layer (the input layer) to the last layer (the output layer), possibly after traversing the layers multiple times.': [0, 0, 15], 'The original goal of the ANN approach was to solve problems in the same way that a human brain would.': [0, 0, 10], 'However, over time, attention moved to performing specific tasks, leading to deviations from biology.': [0, 0, 10], 'Artificial neural networks have been used on a variety of tasks, including computer vision, speech recognition, machine translation, social network filtering, playing board and video games and medical diagnosis.': [0, 0, 22], 'Deep learning consists of multiple hidden layers in an artificial neural network.': [0.8706610357857967, 1, 9], 'This approach tries to model the way the human brain processes light and sound into vision and hearing.': [0, 0, 11], 'Some successful applications of deep learning are computer vision and speech recognition.': [0.8706610357857967, 1, 8], '==== Decision trees ====': [0, 0, 2], "Decision tree learning uses a decision tree as a predictive model to go from observations about an item (represented in the branches) to conclusions about the item's target value (represented in the leaves).": [0.8706610357857967, 1, 19], 'It is one of the predictive modeling approaches used in statistics, data mining and machine learning.': [0.8706610357857967, 1, 10], 'Tree models where the target variable can take a discrete set of values are called classification trees; in these tree structures, leaves represent class labels and branches represent conjunctions of features that lead to those class labels.': [0, 0, 24], 'Decision trees where the target variable can take continuous values (typically real numbers) are called regression trees.': [0, 0, 13], 'In decision analysis, a decision tree can be used to visually and explicitly represent decisions and decision making.': [0, 0, 11], 'In data mining, a decision tree describes data, but the resulting classification tree can be an input for decision making.': [0, 0, 12], '==== Support vector machines ====': [0, 0, 3], 'Support vector machines (SVMs), also known as support vector networks, are a set of related supervised learning methods used for classification and regression.': [3.9677458036000752, 2, 17], 'Given a set of training examples, each marked as belonging to one of two categories, an SVM training algorithm builds a model that predicts whether a new example falls into one category or the other.': [0, 0, 21], 'An SVM training algorithm is a non-probabilistic, binary, linear classifier, although methods such as Platt scaling exist to use SVM in a probabilistic classification setting.': [0, 0, 17], 'In addition to performing linear classification, SVMs can efficiently perform a non-linear classification using what is called the kernel trick, implicitly mapping their inputs into high-dimensional feature spaces.': [0, 0, 19], '==== Regression analysis ====': [0, 0, 2], 'Regression analysis encompasses a large variety of statistical methods to estimate the relationship between input variables and their associated features.': [0, 0, 13], 'Its most common form is linear regression, where a single line is drawn to best fit the given data according to a mathematical criterion such as ordinary least squares.': [0, 0, 17], 'The latter is often extended by regularization (mathematics) methods to mitigate overfitting and bias, as in ridge regression.': [0, 0, 11], 'When dealing with non-linear problems, go-to models include polynomial regression (for example, used for trendline fitting in Microsoft Excel ), Logistic regression (often used in statistical classification) or even kernel regression, which introduces non-linearity by taking advantage of the kernel trick to implicitly map input variables to higher dimensional space.': [0, 0, 36], '==== Bayesian networks ====': [0, 0, 2], 'A Bayesian network, belief network or directed acyclic graphical model is a probabilistic graphical model that represents a set of random variables and their conditional independence with a directed acyclic graph (DAG).': [0, 0, 21], 'For example, a Bayesian network could represent the probabilistic relationships between diseases and symptoms.': [0, 0, 9], 'Given symptoms, the network can be used to compute the probabilities of the presence of various diseases.': [0, 0, 9], 'Efficient algorithms exist that perform inference and learning.': [0.8706610357857967, 1, 6], 'Bayesian networks that model sequences of variables, like speech signals or protein sequences, are called dynamic Bayesian networks.': [0, 0, 14], 'Generalizations of Bayesian networks that can represent and solve decision problems under uncertainty are called influence diagrams.': [0, 0, 11], '==== Genetic algorithms ====': [0, 0, 2], 'A genetic algorithm (GA) is a search algorithm and heuristic technique that mimics the process of natural selection, using methods such as mutation and crossover to generate new genotypes in the hope of finding good solutions to a given problem.': [0, 0, 24], 'In machine learning, genetic algorithms were used in the 1980s and 1990s.': [0.8706610357857967, 1, 7], 'Conversely, machine learning techniques have been used to improve the performance of genetic and evolutionary algorithms.': [0.8706610357857967, 1, 10], '=== Training models ===': [0, 0, 2], 'Usually, machine learning models require a lot of data in order for them to perform well.': [0.8706610357857967, 1, 10], 'Usually, when training a machine learning model, one needs to collect a large, representative sample of data from a training set.': [0.8706610357857967, 1, 14], 'Data from the training set can be as varied as a corpus of text, a collection of images, and data collected from individual users of a service.': [0, 0, 13], 'Overfitting is something to watch out for when training a machine learning model.': [0.8706610357857967, 1, 7], '==== Federated learning ====': [0.8706610357857967, 1, 2], "Federated learning is a new approach to training machine learning models that decentralizes the training process, allowing for users' privacy to be maintained by not needing to send their data to a centralized server.": [1.7413220715715934, 2, 20], 'This also increases efficiency by decentralizing the training process to many devices.': [0, 0, 8], "For example, Gboard uses federated machine learning to train search query prediction models on users' mobile phones without having to send individual searches back to Google.": [0.8706610357857967, 1, 20], '== Applications ==': [0, 0, 1], 'There are many applications for machine learning, including:': [0.8706610357857967, 1, 5], 'In 2006, the media-services provider Netflix held the first "Netflix Prize" competition to find a program to better predict user preferences and improve the accuracy on its existing Cinematch movie recommendation algorithm by at least 10%.': [0, 0, 22], 'A joint team made up of researchers from AT&T Labs-Research in collaboration with the teams Big Chaos and Pragmatic Theory built an ensemble model to win the Grand Prize in 2009 for $1 million.': [0, 0, 18], 'Shortly after the prize was awarded, Netflix realized that viewers\' ratings were not the best indicators of their viewing patterns ("everything is a recommendation") and they changed their recommendation engine accordingly.': [0, 0, 17], 'In 2010 The Wall Street Journal wrote about the firm Rebellion Research and their use of machine learning to predict the financial crisis.': [0.8706610357857967, 1, 13], "In 2012, co-founder of Sun Microsystems, Vinod Khosla, predicted that 80% of medical doctors' jobs would be lost in the next two decades to automated machine learning medical diagnostic software.": [0.8706610357857967, 1, 20], 'In 2014, it was reported that a machine learning algorithm had been applied in the field of art history to study fine art paintings, and that it may have revealed previously unrecognized influences among artists.': [0.8706610357857967, 1, 19], 'In 2019 Springer Nature published the first research book created using machine learning.': [0.8706610357857967, 1, 10], '== Limitations ==': [0, 0, 1], 'Although machine learning has been transformative in some fields, machine-learning programs often fail to deliver expected results.': [0.8706610357857967, 1, 12], 'Reasons for this are numerous: lack of (suitable) data, lack of access to the data, data bias, privacy problems, badly chosen tasks and algorithms, wrong tools and people, lack of resources, and evaluation problems.': [0, 0, 23], 'In 2018, a self-driving car from Uber failed to detect a pedestrian, who was killed after a collision.': [0, 0, 8], 'Attempts to use machine learning in healthcare with the IBM Watson system failed to deliver even after years of time and billions of investment.': [0.8706610357857967, 1, 15], '=== Bias ===': [0, 0, 1], 'Machine learning approaches in particular can suffer from different data biases.': [0.8706610357857967, 1, 8], 'A machine learning system trained on current customers only may not be able to predict the needs of new customer groups that are not represented in the training data.': [0.8706610357857967, 1, 16], 'When trained on man-made data, machine learning is likely to pick up the same constitutional and unconscious biases already present in society.': [0.8706610357857967, 1, 13], 'Language models learned from data have been shown to contain human-like biases.': [0, 0, 8], 'Machine learning systems used for criminal risk assessment have been found to be biased against black people.': [0.8706610357857967, 1, 11], 'In 2015, Google photos would often tag black people as gorillas, and in 2018 this still was not well resolved, but Google reportedly was still using the workaround to remove all gorillas from the training data, and thus was not able to recognize real gorillas at all.': [0, 0, 25], 'Similar issues with recognizing non-white people have been found in many other systems.': [0, 0, 8], 'In 2016, Microsoft tested a chatbot that learned from Twitter, and it quickly picked up racist and sexist language.': [0, 0, 10], 'Because of such challenges, the effective use of machine learning may take longer to be adopted in other domains.': [0.8706610357857967, 1, 10], 'Concern for fairness in machine learning, that is, reducing bias in machine learning and propelling its use for human good is increasingly expressed by artificial intelligence scientists, including Fei-Fei Li, who reminds engineers that "There’s nothing artificial about AI...It’s inspired by people, it’s created by people, and—most importantly—it impacts people.': [1.7413220715715934, 2, 33], 'It is a powerful tool we are only just beginning to understand, and that is a profound responsibility.”': [0, 0, 6], '== Model assessments ==': [0, 0, 2], 'Classification machine learning models can be validated by accuracy estimation techniques like the Holdout method, which splits the data in a training and test set (conventionally 2/3 training set and 1/3 test set designation) and evaluates the performance of the training model on the test set.': [0.8706610357857967, 1, 28], 'In comparison, the K-fold-cross-validation method randomly partitions the data into K subsets and then K experiments are performed each respectively considering 1 subset for evaluation and the remaining K-1 subsets for training the model.': [0, 0, 20], 'In addition to the holdout and cross-validation methods, bootstrap, which samples n instances with replacement from the dataset, can be used to assess model accuracy.': [0, 0, 14], 'In addition to overall accuracy, investigators frequently report sensitivity and specificity meaning True Positive Rate (TPR) and True Negative Rate (TNR) respectively.': [0, 0, 18], 'Similarly, investigators sometimes report the False Positive Rate (FPR) as well as the False Negative Rate (FNR).': [0, 0, 13], 'However, these rates are ratios that fail to reveal their numerators and denominators.': [0, 0, 7], "The Total Operating Characteristic (TOC) is an effective method to express a model's diagnostic ability.": [0, 0, 10], "TOC shows the numerators and denominators of the previously mentioned rates, thus TOC provides more information than the commonly used Receiver Operating Characteristic (ROC) and ROC's associated Area Under the Curve (AUC).": [0, 0, 22], '== Ethics ==': [0, 0, 1], 'Machine learning poses a host of ethical questions.': [0.8706610357857967, 1, 6], 'Systems which are trained on datasets collected with biases may exhibit these biases upon use (algorithmic bias), thus digitizing cultural prejudices.': [0, 0, 16], 'For example, using job hiring data from a firm with racist hiring policies may lead to a machine learning system duplicating the bias by scoring job applicants against similarity to previous successful applicants.': [0.8706610357857967, 1, 23], 'Responsible collection of data and documentation of algorithmic rules used by a system thus is a critical part of machine learning.': [0.8706610357857967, 1, 13], 'Because human languages contain biases, machines trained on language corpora will necessarily also learn these biases.': [0, 0, 12], 'Other forms of ethical challenges, not related to personal biases, are more seen in health care.': [0, 0, 9], "There are concerns among health care professionals that these systems might not be designed in the public's interest but as income-generating machines.": [0, 0, 12], 'This is especially true in the United States where there is a long-standing ethical dilemma of improving health care, but also increasing profits.': [0, 0, 13], "For example, the algorithms could be designed to provide patients with unnecessary tests or medication in which the algorithm's proprietary owners hold stakes.": [0, 0, 14], 'There is huge potential for machine learning in health care to provide professionals a great tool to diagnose, medicate, and even plan recovery paths for patients, but this will not happen until the personal biases mentioned previously, and these "greed" biases are addressed.': [0.8706610357857967, 1, 25], '== Software ==': [0, 0, 1], 'Software suites containing a variety of machine learning algorithms include the following:': [0.8706610357857967, 1, 9], '=== Free and open-source software ===': [0, 0, 3], '=== Proprietary software with free and open-source editions ===': [0, 0, 5], '=== Proprietary software ===': [0, 0, 2], '== Journals ==': [0, 0, 1], 'Journal of Machine Learning Research': [0.8706610357857967, 1, 4], 'Machine Learning': [0.8706610357857967, 1, 2], 'Nature Machine Intelligence': [0, 0, 3], 'Neural Computation': [0, 0, 2], '== Conferences ==': [0, 0, 1], 'Conference on Neural Information Processing Systems': [0, 0, 5], 'International Conference on Machine Learning': [0.8706610357857967, 1, 4], '== See also ==': [0, 0, 2], '== References ==': [0, 0, 1], '== Further reading ==': [0, 0, 1], '== External links ==': [0, 0, 2], 'International Machine Learning Society': [0.8706610357857967, 1, 4], 'mloss is an academic database of open-source machine learning software.': [0.8706610357857967, 1, 7], 'Machine Learning Crash Course by Google.': [0.8706610357857967, 1, 5], 'This is a free course on machine learning through the use of TensorFlow.': [0.8706610357857967, 1, 6]}

# %%
dataset={'https://en.wikipedia.org/wiki/Machine_learning': (0, 0, 2), 'Machine learning (ML) is the study of computer algorithms that improve automatically through experience.': (0.8706610357857967, 1, 9), 'It is seen as a subset of artificial intelligence.': (0, 0, 4), 'Machine learning algorithms build a mathematical model based on sample data, known as "training data", in order to make predictions or decisions without being explicitly programmed to do so.': (0.8706610357857967, 1, 19), 'Machine learning algorithms are used in a wide variety of applications, such as email filtering and computer vision, where it is difficult or infeasible to develop  conventional algorithms to perform the needed tasks.': (0.8706610357857967, 1, 19), 'Machine learning is closely related to computational statistics, which focuses on making predictions using computers.': (0.8706610357857967, 1, 11), 'The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning.': (0.8706610357857967, 1, 11), 'Data mining is a related field of study, focusing on exploratory data analysis through unsupervised learning.': (0.8706610357857967, 1, 11), 'In its application across business problems, machine learning is also referred to as predictive analytics.': (0.8706610357857967, 1, 10), '== Overview ==': (0, 0, 1), 'Machine learning involves computers discovering how they can perform tasks without being explicitly programmed to do so.': (0.8706610357857967, 1, 10), 'For early tasks that humans assigned to computers, it was possible to create algorithms telling the machine how to execute all needed steps to solve the problem in hand.': (0, 0, 16), "So on the computer's part, no learning was needed.": (0.8706610357857967, 1, 4), 'For more advanced tasks, it can be challenging for a human to manually create the needed algorithms.': (0, 0, 8), 'In practice, it can turn out to be more effective to help the machine develop its own algorithm, rather than have human programmers specify every needed step.': (0, 0, 14), 'The discipline of machine learning employs various approaches to help computers learn to accomplish tasks for which no fully satisfactory algorithm exists.': (0.8706610357857967, 1, 15), 'For example, for cases where vast numbers of potential answers exist, some of the correct ones can be labelled as valid, and this can be used as training data for the computer to improve the algorithm(s) it uses to determine correct answers.': (0, 0, 21), '=== Machine learning approaches ===': (0.8706610357857967, 1, 3), 'Early classifications for machine learning approaches sometimes divided them into three broad categories, depending on the nature of the "signal" or "feedback" available to the learning system.': (1.7413220715715934, 2, 17), 'Supervised learning:  The computer is presented with example inputs and their desired outputs, given by a "teacher", and the goal is to learn a general rule that maps inputs to outputs.': (3.9677458036000752, 2, 17), 'Unsupervised learning:  No labels are given to the learning algorithm, leaving it on its own to find structure in its input.': (1.7413220715715934, 2, 10), 'Unsupervised learning can be a goal in itself (discovering hidden patterns in data) or a means towards an end (feature learning).': (1.7413220715715934, 2, 12), "Reinforcement learning:  A computer program interacts with a dynamic environment in which it must perform a certain goal (such as driving a vehicle or playing a game against an opponent) As it navigates its problem space, the program is provided feedback that's analogous to rewards, which it tries to maximise.": (0.8706610357857967, 1, 26), "Other approaches or processes have since developed that don't fit neatly into this three-fold categorisation, and sometimes more than one is used by the same machine learning system.": (0.8706610357857967, 1, 15), 'For example topic modeling, dimensionality reduction or meta learning.': (0.8706610357857967, 1, 7), 'As of 2020, deep learning had become the dominant approach for much ongoing work in the field of machine learning .': (1.7413220715715934, 2, 11), '== History and relationships to other fields ==': (0, 0, 3), 'The term machine learning was coined in 1959 by Arthur Samuel, an American IBMer and pioneer in the field of computer gaming and artificial intelligence.': (0.8706610357857967, 1, 14), "A representative book of the machine learning research during the 1960s was the Nilsson's book on Learning Machines, dealing mostly with machine learning for pattern classification.": (2.61198310735739, 3, 16), 'Interest related to pattern recognition continued into the 1970s, as described by Duda and Hart in 1973.': (0, 0, 9), 'In 1981 a report was given on using teaching strategies so that a neural network learns to recognize 40 characters (26 letters, 10 digits, and 4 special symbols) from a computer terminal.': (0, 0, 16), 'Tom M. Mitchell provided a widely quoted, more formal definition of the algorithms studied in the machine learning field: "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P if its performance at tasks in T, as measured by P,  improves with experience E." This definition of the tasks in which machine learning is concerned offers a fundamentally operational definition rather than defining the field in cognitive terms.': (1.7413220715715934, 2, 45), 'This follows Alan Turing\'s proposal in his paper "Computing Machinery and Intelligence", in which the question "Can machines think?"': (0, 0, 11), 'is replaced with the question "Can machines do what we (as thinking entities) can do?': (0, 0, 5), '=== Relation to artificial intelligence ===': (0, 0, 3), 'As a scientific endeavor, machine learning grew out of the quest for artificial intelligence.': (0.8706610357857967, 1, 8), 'In the early days of AI as an academic discipline, some researchers were interested in having machines learn from data.': (0, 0, 10), 'They attempted to approach the problem with various symbolic methods, as well as what were then termed "neural networks"; these were mostly perceptrons and other models that were later found to be reinventions of the generalized linear models of statistics.': (0, 0, 20), 'Probabilistic reasoning was also employed, especially in automated medical diagnosis.': (0, 0, 8), 'However, an increasing emphasis on the logical, knowledge-based approach caused a rift between AI and machine learning.': (0.8706610357857967, 1, 11), 'Probabilistic systems were plagued by theoretical and practical problems of data acquisition and representation.': (0, 0, 9), 'By 1980, expert systems had come to dominate AI, and statistics was out of favor.': (0, 0, 7), 'Work on symbolic/knowledge-based learning did continue within AI, leading to inductive logic programming, but the more statistical line of research was now outside the field of AI proper, in pattern recognition and information retrieval.': (0.8706610357857967, 1, 21), 'Neural networks research had been abandoned by AI and computer science around the same time.': (0, 0, 9), 'This line, too, was continued outside the AI/CS field, as "connectionism", by researchers from other disciplines including Hopfield, Rumelhart and Hinton.': (0, 0, 12), 'Their main success came in the mid-1980s with the reinvention of backpropagation.': (0, 0, 6), 'Machine learning, reorganized as a separate field, started to flourish in the 1990s.': (0.8706610357857967, 1, 8), 'The field changed its goal from achieving artificial intelligence to tackling solvable problems of a practical nature.': (0, 0, 11), 'It shifted focus away from the symbolic approaches it had inherited from AI, and toward methods and models borrowed from statistics and probability theory.': (0, 0, 14), 'As of 2019, many sources continue to assert that machine learning remains a sub field of AI.': (0.8706610357857967, 1, 10), 'Yet some practitioners, for example Dr Daniel Hulme, who both teaches AI and  runs a company operating in the field, argues that machine learning and AI are separate.': (0.8706610357857967, 1, 17), '=== Relation to data mining ===': (0, 0, 3), 'Machine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases).': (1.7413220715715934, 2, 32), 'Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy.': (2.61198310735739, 3, 24), 'Much of the confusion between these two research communities (which do often have separate conferences and separate journals, ECML PKDD being a major exception) comes from the basic assumptions they work with: in machine learning, performance is usually evaluated with respect to the ability to reproduce known knowledge, while in knowledge discovery and data mining (KDD) the key task is the discovery of previously unknown knowledge.': (0.8706610357857967, 1, 39), 'Evaluated with respect to known knowledge, an uninformed (unsupervised) method will easily be outperformed by other supervised methods, while in a typical KDD task, supervised methods cannot be used due to the unavailability of training data.': (6.194169535628557, 2, 21), '=== Relation to optimization ===': (0, 0, 2), 'Machine learning also has intimate ties to optimization: many learning problems are formulated as minimization of some loss function on a training set of examples.': (1.7413220715715934, 2, 16), 'Loss functions express the discrepancy between the predictions of the model being trained and the actual problem instances (for example, in classification, one wants to assign a label to instances, and models are trained to correctly predict the pre-assigned labels of a set of examples).': (0, 0, 25), 'The difference between the two fields arises from the goal of generalization: while optimization algorithms can minimize the loss on a training set, machine learning is concerned with minimizing the loss on unseen samples.': (0.8706610357857967, 1, 19), '=== Relation to statistics ===': (0, 0, 2), 'Machine learning and statistics are closely related fields in terms of methods, but distinct in their principal goal: statistics draws population inferences from a sample, while machine learning finds generalizable predictive patterns.': (1.7413220715715934, 2, 22), 'According to Michael I. Jordan, the ideas of machine learning, from methodological principles to theoretical tools, have had a long pre-history in statistics.': (0.8706610357857967, 1, 13), 'He also suggested the term data science as a placeholder to call the overall field.': (0, 0, 9), 'Leo Breiman distinguished two statistical modeling paradigms: data model and algorithmic model, wherein "algorithmic model" means more or less the machine learning algorithms like Random forest.': (0.8706610357857967, 1, 22), 'Some statisticians have adopted methods from machine learning, leading to a combined field that they call statistical learning.': (1.7413220715715934, 2, 11), '== Theory ==': (0, 0, 1), 'A core objective of a learner is to generalize from its experience.': (0, 0, 5), 'Generalization in this context is the ability of a learning machine to perform accurately on new, unseen examples/tasks after having experienced a learning data set.': (1.7413220715715934, 2, 14), 'The training examples come from some generally unknown probability distribution (considered representative of the space of occurrences) and the learner has to build a general model about this space that enables it to produce sufficiently accurate predictions in new cases.': (0, 0, 23), 'The computational analysis of machine learning algorithms and their performance is a branch of theoretical computer science known as computational learning theory.': (1.7413220715715934, 2, 14), 'Because training sets are finite and the future is uncertain, learning theory usually does not yield guarantees of the performance of algorithms.': (0.8706610357857967, 1, 12), 'Instead, probabilistic bounds on the performance are quite common.': (0, 0, 6), 'The bias–variance decomposition is one way to quantify generalization error.': (0, 0, 7), 'For the best performance in the context of generalization, the complexity of the hypothesis should match the complexity of the function underlying the data.': (0, 0, 11), 'If the hypothesis is less complex than the function, then the model has under fitted the data.': (0, 0, 7), 'If the complexity of the model is increased in response, then the training error decreases.': (0, 0, 7), 'But if the hypothesis is too complex, then the model is subject to overfitting and generalization will be poorer.': (0, 0, 7), 'In addition to performance bounds, learning theorists study the time complexity and feasibility of learning.': (1.7413220715715934, 2, 10), 'In computational learning theory, a computation is considered feasible if it can be done in polynomial time.': (0.8706610357857967, 1, 9), 'There are two kinds of time complexity results.': (0, 0, 5), 'Positive results show that a certain class of functions can be learned in polynomial time.': (0, 0, 9), 'Negative results show that certain classes cannot be learned in polynomial time.': (0, 0, 8), '== Approaches ==': (0, 0, 1), '=== Types of learning algorithms ===': (5.289501643582395, 2, 3), 'The types of machine learning algorithms differ in their approach, the type of data they input and output, and the type of task or problem that they are intended to solve.': (5.289501643582395, 2, 15), '==== Supervised learning ====': (3.9677458036000752, 2, 2), 'Supervised learning algorithms build a mathematical model of a set of data that contains both the inputs and the desired outputs.': (3.9677458036000752, 2, 12), 'The data is known as training data, and consists of a set of training examples.': (0, 0, 8), 'Each training example has one or more inputs and the desired output, also known as a supervisory signal.': (0, 0, 10), 'In the mathematical model, each training example is represented by an array or vector, sometimes called a feature vector, and the training data is represented by a matrix.': (0, 0, 15), 'Through iterative optimization of an objective function, supervised learning algorithms learn a function that can be used to predict the output associated with new inputs.': (3.9677458036000752, 2, 15), 'An optimal function will allow the algorithm to correctly determine the output for inputs that were not a part of the training data.': (0, 0, 11), 'An algorithm that improves the accuracy of its outputs or predictions over time is said to have learned to perform that task.': (0, 0, 10), 'Types of supervised learning algorithms include Active learning , classification and regression.': (9.25724744718247, 4, 9), 'Classification algorithms are used when the outputs are restricted to a limited set of values, and regression algorithms are used when the outputs may have any numerical value within a range.': (0, 0, 17), 'As an example, for a classification algorithm that filters emails, the input would be an incoming email, and the output would be the name of the folder in which to file the email.': (0, 0, 15), 'Similarity learning is an area of supervised machine learning closely related to regression and classification, but the goal is to learn from examples using a similarity function that measures how similar or related two objects are.': (4.838406839385872, 3, 21), 'It has applications in ranking, recommendation systems, visual identity tracking, face verification, and speaker verification.': (0, 0, 11), '==== Unsupervised learning ====': (0.8706610357857967, 1, 2), 'Unsupervised learning algorithms take a set of data that contains only inputs, and find structure in the data, like grouping or clustering of data points.': (0.8706610357857967, 1, 16), 'The algorithms, therefore, learn from test data that has not been labeled, classified or categorized.': (0, 0, 8), 'Instead of responding to feedback, unsupervised learning algorithms identify commonalities in the data and react based on the presence or absence of such commonalities in each new piece of data.': (0.8706610357857967, 1, 17), 'A central application of unsupervised learning is in the field of density estimation in statistics, such as finding the probability density function.': (0.8706610357857967, 1, 12), 'Though unsupervised learning encompasses other domains involving summarizing and explaining data features.': (0.8706610357857967, 1, 10), 'Cluster analysis is the assignment of a set of observations into subsets (called clusters) so that observations within the same cluster are similar according to one or more predesignated criteria, while observations drawn from different clusters are dissimilar.': (0, 0, 21), 'Different clustering techniques make different assumptions on the structure of the data, often defined by some similarity metric and evaluated, for example, by internal compactness, or the similarity between members of the same cluster, and separation, the difference between clusters.': (0, 0, 22), 'Other methods are based on estimated density and graph connectivity.': (0, 0, 6), '==== Semi-supervised learning ====': (0.8706610357857967, 1, 2), 'Semi-supervised learning falls between unsupervised learning (without any labeled training data) and supervised learning (with completely labeled training data).': (5.709067875171669, 4, 15), 'Some of the training examples are missing training labels,  yet many machine-learning researchers have found that unlabeled data, when used in conjunction with a small amount of labeled data, can produce a considerable improvement in learning accuracy.': (0.8706610357857967, 1, 23), 'In weakly supervised learning, the training labels are noisy, limited, or imprecise; however, these labels are often cheaper to obtain, resulting in larger effective training sets.': (3.9677458036000752, 2, 18), '==== Reinforcement learning ====': (0.8706610357857967, 1, 2), 'Reinforcement learning is an area of machine learning concerned with how software agents ought to take actions in an environment so as to maximize some notion of cumulative reward.': (1.7413220715715934, 2, 16), 'Due to its generality, the field is studied in many other disciplines, such as game theory, control theory, operations research, information theory, simulation-based optimization, multi-agent systems, swarm intelligence, statistics and genetic algorithms.': (0, 0, 23), 'In machine learning, the environment is typically represented as a Markov Decision Process (MDP).': (0.8706610357857967, 1, 9), 'Many reinforcement learning algorithms use dynamic programming techniques.': (0.8706610357857967, 1, 8), 'Reinforcement learning algorithms do not assume knowledge of an exact mathematical model of the MDP, and are used when exact models are infeasible.': (0.8706610357857967, 1, 13), 'Reinforcement learning algorithms are used in autonomous vehicles or in learning to play a game against a human opponent.': (1.7413220715715934, 2, 11), '==== Self learning ====': (0.8706610357857967, 1, 2), 'Self-learning as machine learning paradigm was introduced in 1982 along with a neural network capable of self-learning  named Crossbar Adaptive Array (CAA).': (0.8706610357857967, 1, 15), 'It is a learning with no external rewards and no external teacher advices.': (0.8706610357857967, 1, 6), 'The CAA self-learning algorithm computes, in a crossbar fashion, both decisions about actions and emotions (feelings) about consequence situations.': (0, 0, 12), 'The system is driven by the interaction between cognition and emotion.': (0, 0, 5), 'The self-learning algorithm updates a memory matrix W =||w(a,s)|| such that in each iteration executes the following machine learning  routine:': (0.8706610357857967, 1, 13), ' In situation s perform action a;': (0, 0, 3), ' Receive consequence situation s’;': (0, 0, 3), ' Compute emotion of being in consequence situation v(s’);': (0, 0, 5), ' Update crossbar memory  w’(a,s) = w(a,s) + v(s’).': (0, 0, 6), 'It is a system with only one input, situation s, and only one output, action (or behavior) a.': (0, 0, 8), 'There is neither a separate reinforcement input nor an advice input from the environment.': (0, 0, 7), 'The backpropagated value (secondary reinforcement) is the emotion toward the consequence situation.': (0, 0, 8), 'The CAA exists in two environments, one is behavioral environment where it behaves, and the other is genetic environment, wherefrom it initially and only once receives initial emotions about situations to be encountered in the  behavioral environment.': (0, 0, 19), 'After receiving the genome (species) vector from the genetic environment, the CAA learns a goal seeking behavior, in an environment that contains both desirable and undesirable situations.': (0, 0, 16), '==== Feature learning ====': (0.8706610357857967, 1, 2), 'Several learning algorithms aim at discovering better representations of the inputs provided during training.': (0.8706610357857967, 1, 10), 'Classic examples include principal components analysis and cluster analysis.': (0, 0, 8), 'Feature learning algorithms, also called representation learning algorithms, often attempt to preserve the information in their input but also transform it in a way that makes it useful, often as a pre-processing step before performing classification or predictions.': (1.7413220715715934, 2, 24), 'This technique allows reconstruction of the inputs coming from the unknown data-generating distribution, while not being necessarily faithful to configurations that are implausible under that distribution.': (0, 0, 13), 'This replaces manual feature engineering, and allows a machine to both learn the features and use them to perform a specific task.': (0, 0, 12), 'Feature learning can be either supervised or unsupervised.': (3.9677458036000752, 2, 5), 'In supervised feature learning, features are learned using labeled input data.': (3.9677458036000752, 2, 9), 'Examples include artificial neural networks, multilayer perceptrons, and supervised dictionary learning.': (3.9677458036000752, 2, 10), 'In unsupervised feature learning, features are learned with unlabeled input data.': (0.8706610357857967, 1, 8), 'Examples include dictionary learning, independent component analysis, autoencoders, matrix factorization and various forms of clustering.': (0.8706610357857967, 1, 13), 'Manifold learning algorithms attempt to do so under the constraint that the learned representation is low-dimensional.': (0.8706610357857967, 1, 8), 'Sparse coding algorithms attempt to do so under the constraint that the learned representation is sparse, meaning that the mathematical model has many zeros.': (0, 0, 13), 'Multilinear subspace learning algorithms aim to learn low-dimensional representations directly from tensor representations for multidimensional data, without reshaping them into higher-dimensional vectors.': (0.8706610357857967, 1, 17), 'Deep learning algorithms discover multiple levels of representation, or a hierarchy of features, with higher-level, more abstract features defined in terms of (or generating) lower-level features.': (0.8706610357857967, 1, 17), 'It has been argued that an intelligent machine is one that learns a representation that disentangles the underlying factors of variation that explain the observed data.': (0, 0, 13), 'Feature learning is motivated by the fact that machine learning tasks such as classification often require input that is mathematically and computationally convenient to process.': (1.7413220715715934, 2, 15), 'However, real-world data such as images, video, and sensory data has not yielded to attempts to algorithmically define specific features.': (0, 0, 13), 'An alternative is to discover such features or representations through examination, without relying on explicit algorithms.': (0, 0, 9), '==== Sparse dictionary learning ====': (0.8706610357857967, 1, 3), 'Sparse dictionary learning is a feature learning method where a training example is represented as a linear combination of basis functions, and is assumed to be a sparse matrix.': (1.7413220715715934, 2, 16), 'The method is strongly NP-hard and difficult to solve approximately.': (0, 0, 6), 'A popular heuristic method for sparse dictionary learning is the K-SVD algorithm.': (0.8706610357857967, 1, 8), 'Sparse dictionary learning has been applied in several contexts.': (0.8706610357857967, 1, 6), 'In classification, the problem is to determine the class to which a previously unseen training example belongs.': (0, 0, 9), 'For a dictionary where each class has already been built, a new training example is associated with the class that is best sparsely represented by the corresponding dictionary.': (0, 0, 14), 'Sparse dictionary learning has also been applied in image de-noising.': (0.8706610357857967, 1, 7), 'The key idea is that a clean image patch can be sparsely represented by an image dictionary, but the noise cannot.': (0, 0, 10), '==== Anomaly detection ====': (0, 0, 2), 'In data mining, anomaly detection, also known as outlier detection, is the identification of rare items, events or observations which raise suspicions by differing significantly from the majority of the data.': (0, 0, 19), 'Typically, the anomalous items represent an issue such as bank fraud, a structural defect, medical problems or errors in a text.': (0, 0, 13), 'Anomalies are referred to as outliers, novelties, noise, deviations and exceptions.': (0, 0, 7), 'In particular, in the context of abuse and network intrusion detection, the interesting objects are often not rare objects, but unexpected bursts in activity.': (0, 0, 14), 'This pattern does not adhere to the common statistical definition of an outlier as a rare object, and many outlier detection methods (in particular, unsupervised algorithms) will fail on such data, unless it has been aggregated appropriately.': (0, 0, 20), 'Instead, a cluster analysis algorithm may be able to detect the micro-clusters formed by these patterns.': (0, 0, 10), 'Three broad categories of anomaly detection techniques exist.': (0, 0, 7), 'Unsupervised anomaly detection techniques detect anomalies in an unlabeled test data set under the assumption that the majority of the instances in the data set are normal, by looking for instances that seem to fit least to the remainder of the data set.': (0, 0, 24), 'Supervised anomaly detection techniques require a data set that has been labeled as "normal" and "abnormal" and involves training a classifier (the key difference to many other statistical classification problems is the inherently unbalanced nature of outlier detection).': (3.0970847678142785, 1, 24), 'Semi-supervised anomaly detection techniques construct a model representing normal behavior from a given normal training data set and then test the likelihood of a test instance to be generated by the model.': (0, 0, 20), '==== Robot learning ====': (0.8706610357857967, 1, 2), 'In developmental robotics, robot learning algorithms generate their own sequences of learning experiences, also known as a curriculum, to cumulatively acquire new skills through self-guided exploration and social interaction with humans.': (1.7413220715715934, 2, 21), 'These robots use guidance mechanisms such as active learning, maturation, motor synergies and imitation.': (0.8706610357857967, 1, 10), '==== Association rules ====': (0, 0, 2), 'Association rule learning is a rule-based machine learning method for discovering relationships between variables in large databases.': (1.7413220715715934, 2, 12), 'It is intended to identify strong rules discovered in databases using some measure of "interestingness".Rule-based machine learning is a general term for any machine learning method that identifies, learns, or evolves "rules" to store, manipulate or apply knowledge.': (1.7413220715715934, 2, 25), 'The defining characteristic of a rule-based machine learning algorithm is the identification and utilization of a set of relational rules that collectively represent the knowledge captured by the system.': (0.8706610357857967, 1, 16), 'This is in contrast to other machine learning algorithms that commonly identify a singular model that can be universally applied to any instance in order to make a prediction.': (0.8706610357857967, 1, 14), 'Rule-based machine learning approaches include learning classifier systems, association rule learning, and artificial immune systems.': (2.61198310735739, 3, 14), 'Based on the concept of strong rules, Rakesh Agrawal, Tomasz Imieliński and Arun Swami introduced association rules for discovering regularities between products in large-scale transaction data recorded by point-of-sale (POS) systems in supermarkets.': (0, 0, 24), 'For example, the rule': (0, 0, 2), '          n': (0, 0, 1), '          p': (0, 0, 1), '          e': (0, 0, 1), '          b': (0, 0, 1), '          u': (0, 0, 1), '          r': (0, 0, 1), '          g': (0, 0, 1), '    {\\displaystyle \\{\\mathrm {onions,potatoes} \\}\\Rightarrow \\{\\mathrm {burger} \\}}': (0, 0, 7), '   found in the sales data of a supermarket would indicate that if a customer buys onions and potatoes together, they are likely to also buy hamburger meat.': (0, 0, 16), 'Such information can be used as the basis for decisions about marketing activities such as promotional pricing or product placements.': (0, 0, 10), 'In addition to market basket analysis, association rules are employed today in application areas including Web usage mining, intrusion detection, continuous production, and bioinformatics.': (0, 0, 19), 'In contrast with sequence mining, association rule learning typically does not consider the order of items either within a transaction or across transactions.': (0.8706610357857967, 1, 15), 'Learning classifier systems (LCS) are a family of rule-based machine learning algorithms that combine a discovery component, typically a genetic algorithm, with a learning component, performing either supervised learning, reinforcement learning, or unsupervised learning.': (8.321050982529059, 7, 25), 'They seek to identify a set of context-dependent rules that collectively store and apply knowledge in a piecewise manner in order to make predictions.': (0, 0, 14), 'Inductive logic programming (ILP) is an approach to rule-learning using logic programming as a uniform representation for input examples, background knowledge, and hypotheses.': (0, 0, 16), 'Given an encoding of the known background knowledge and a set of examples represented as a logical database of facts, an ILP system will derive a hypothesized logic program that entails all positive and no negative examples.': (0, 0, 21), 'Inductive programming is a related field that considers any kind of programming languages for representing hypotheses (and not only logic programming), such as functional programs.': (0, 0, 14), 'Inductive logic programming is particularly useful in bioinformatics and natural language processing.': (0, 0, 9), 'Gordon Plotkin and Ehud Shapiro laid the initial theoretical foundation for inductive machine learning in a logical setting.': (0.8706610357857967, 1, 13), 'Shapiro built their first implementation (Model Inference System) in 1981: a Prolog program that inductively inferred logic programs from positive and negative examples.': (0, 0, 16), 'The term inductive here refers to philosophical induction, suggesting a theory to explain observed facts, rather than mathematical induction, proving a property for all members of a well-ordered set.': (0, 0, 18), '=== Models ===': (0, 0, 1), 'Performing machine learning involves creating a model, which is trained on some training data and then can process additional data to make predictions.': (0.8706610357857967, 1, 14), 'Various types of models have been used and researched for machine learning systems.': (5.289501643582395, 2, 8), '==== Artificial neural networks ====': (0, 0, 3), 'Artificial neural networks (ANNs), or connectionist systems, are computing systems vaguely inspired by the biological neural networks that constitute animal brains.': (0, 0, 16), 'Such systems "learn" to perform tasks by considering examples, generally without being programmed with any task-specific rules.': (0, 0, 11), 'An ANN is a model based on a collection of connected units or nodes called "artificial neurons", which loosely model the neurons in a biological brain.': (0, 0, 15), 'Each connection, like the synapses in a biological brain, can transmit information, a "signal", from one artificial neuron to another.': (0, 0, 12), 'An artificial neuron that receives a signal can process it and then signal additional artificial neurons connected to it.': (0, 0, 10), 'In common ANN implementations, the signal at a connection between artificial neurons is a real number, and the output of each artificial neuron is computed by some non-linear function of the sum of its inputs.': (0, 0, 17), 'The connections between artificial neurons are called "edges".': (0, 0, 5), 'Artificial neurons and edges typically have a weight that adjusts as learning proceeds.': (0.8706610357857967, 1, 8), 'The weight increases or decreases the strength of the signal at a connection.': (0, 0, 6), 'Artificial neurons may have a threshold such that the signal is only sent if the aggregate signal crosses that threshold.': (0, 0, 10), 'Typically, artificial neurons are aggregated into layers.': (0, 0, 5), 'Different layers may perform different kinds of transformations on their inputs.': (0, 0, 8), 'Signals travel from the first layer (the input layer) to the last layer (the output layer), possibly after traversing the layers multiple times.': (0, 0, 15), 'The original goal of the ANN approach was to solve problems in the same way that a human brain would.': (0, 0, 10), 'However, over time, attention moved to performing specific tasks, leading to deviations from biology.': (0, 0, 10), 'Artificial neural networks have been used on a variety of tasks, including computer vision, speech recognition, machine translation, social network filtering, playing board and video games and medical diagnosis.': (0, 0, 22), 'Deep learning consists of multiple hidden layers in an artificial neural network.': (0.8706610357857967, 1, 9), 'This approach tries to model the way the human brain processes light and sound into vision and hearing.': (0, 0, 11), 'Some successful applications of deep learning are computer vision and speech recognition.': (0.8706610357857967, 1, 8), '==== Decision trees ====': (0, 0, 2), "Decision tree learning uses a decision tree as a predictive model to go from observations about an item (represented in the branches) to conclusions about the item's target value (represented in the leaves).": (0.8706610357857967, 1, 19), 'It is one of the predictive modeling approaches used in statistics, data mining and machine learning.': (0.8706610357857967, 1, 10), 'Tree models where the target variable can take a discrete set of values are called classification trees; in these tree structures, leaves represent class labels and branches represent conjunctions of features that lead to those class labels.': (0, 0, 24), 'Decision trees where the target variable can take continuous values (typically real numbers) are called regression trees.': (0, 0, 13), 'In decision analysis, a decision tree can be used to visually and explicitly represent decisions and decision making.': (0, 0, 11), 'In data mining, a decision tree describes data, but the resulting classification tree can be an input for decision making.': (0, 0, 12), '==== Support vector machines ====': (0, 0, 3), 'Support vector machines (SVMs), also known as support vector networks, are a set of related supervised learning methods used for classification and regression.': (3.9677458036000752, 2, 17), 'Given a set of training examples, each marked as belonging to one of two categories, an SVM training algorithm builds a model that predicts whether a new example falls into one category or the other.': (0, 0, 21), 'An SVM training algorithm is a non-probabilistic, binary, linear classifier, although methods such as Platt scaling exist to use SVM in a probabilistic classification setting.': (0, 0, 17), 'In addition to performing linear classification, SVMs can efficiently perform a non-linear classification using what is called the kernel trick, implicitly mapping their inputs into high-dimensional feature spaces.': (0, 0, 19), '==== Regression analysis ====': (0, 0, 2), 'Regression analysis encompasses a large variety of statistical methods to estimate the relationship between input variables and their associated features.': (0, 0, 13), 'Its most common form is linear regression, where a single line is drawn to best fit the given data according to a mathematical criterion such as ordinary least squares.': (0, 0, 17), 'The latter is often extended by regularization (mathematics) methods to mitigate overfitting and bias, as in ridge regression.': (0, 0, 11), 'When dealing with non-linear problems, go-to models include polynomial regression (for example, used for trendline fitting in Microsoft Excel ), Logistic regression (often used in statistical classification) or even kernel regression, which introduces non-linearity by taking advantage of the kernel trick to implicitly map input variables to higher dimensional space.': (0, 0, 36), '==== Bayesian networks ====': (0, 0, 2), 'A Bayesian network, belief network or directed acyclic graphical model is a probabilistic graphical model that represents a set of random variables and their conditional independence with a directed acyclic graph (DAG).': (0, 0, 21), 'For example, a Bayesian network could represent the probabilistic relationships between diseases and symptoms.': (0, 0, 9), 'Given symptoms, the network can be used to compute the probabilities of the presence of various diseases.': (0, 0, 9), 'Efficient algorithms exist that perform inference and learning.': (0.8706610357857967, 1, 6), 'Bayesian networks that model sequences of variables, like speech signals or protein sequences, are called dynamic Bayesian networks.': (0, 0, 14), 'Generalizations of Bayesian networks that can represent and solve decision problems under uncertainty are called influence diagrams.': (0, 0, 11), '==== Genetic algorithms ====': (0, 0, 2), 'A genetic algorithm (GA) is a search algorithm and heuristic technique that mimics the process of natural selection, using methods such as mutation and crossover to generate new genotypes in the hope of finding good solutions to a given problem.': (0, 0, 24), 'In machine learning, genetic algorithms were used in the 1980s and 1990s.': (0.8706610357857967, 1, 7), 'Conversely, machine learning techniques have been used to improve the performance of genetic and evolutionary algorithms.': (0.8706610357857967, 1, 10), '=== Training models ===': (0, 0, 2), 'Usually, machine learning models require a lot of data in order for them to perform well.': (0.8706610357857967, 1, 10), 'Usually, when training a machine learning model, one needs to collect a large, representative sample of data from a training set.': (0.8706610357857967, 1, 14), 'Data from the training set can be as varied as a corpus of text, a collection of images, and data collected from individual users of a service.': (0, 0, 13), 'Overfitting is something to watch out for when training a machine learning model.': (0.8706610357857967, 1, 7), '==== Federated learning ====': (0.8706610357857967, 1, 2), "Federated learning is a new approach to training machine learning models that decentralizes the training process, allowing for users' privacy to be maintained by not needing to send their data to a centralized server.": (1.7413220715715934, 2, 20), 'This also increases efficiency by decentralizing the training process to many devices.': (0, 0, 8), "For example, Gboard uses federated machine learning to train search query prediction models on users' mobile phones without having to send individual searches back to Google.": (0.8706610357857967, 1, 20), '== Applications ==': (0, 0, 1), 'There are many applications for machine learning, including:': (0.8706610357857967, 1, 5), 'In 2006, the media-services provider Netflix held the first "Netflix Prize" competition to find a program to better predict user preferences and improve the accuracy on its existing Cinematch movie recommendation algorithm by at least 10%.': (0, 0, 22), 'A joint team made up of researchers from AT&T Labs-Research in collaboration with the teams Big Chaos and Pragmatic Theory built an ensemble model to win the Grand Prize in 2009 for $1 million.': (0, 0, 18), 'Shortly after the prize was awarded, Netflix realized that viewers\' ratings were not the best indicators of their viewing patterns ("everything is a recommendation") and they changed their recommendation engine accordingly.': (0, 0, 17), 'In 2010 The Wall Street Journal wrote about the firm Rebellion Research and their use of machine learning to predict the financial crisis.': (0.8706610357857967, 1, 13), "In 2012, co-founder of Sun Microsystems, Vinod Khosla, predicted that 80% of medical doctors' jobs would be lost in the next two decades to automated machine learning medical diagnostic software.": (0.8706610357857967, 1, 20), 'In 2014, it was reported that a machine learning algorithm had been applied in the field of art history to study fine art paintings, and that it may have revealed previously unrecognized influences among artists.': (0.8706610357857967, 1, 19), 'In 2019 Springer Nature published the first research book created using machine learning.': (0.8706610357857967, 1, 10), '== Limitations ==': (0, 0, 1), 'Although machine learning has been transformative in some fields, machine-learning programs often fail to deliver expected results.': (0.8706610357857967, 1, 12), 'Reasons for this are numerous: lack of (suitable) data, lack of access to the data, data bias, privacy problems, badly chosen tasks and algorithms, wrong tools and people, lack of resources, and evaluation problems.': (0, 0, 23), 'In 2018, a self-driving car from Uber failed to detect a pedestrian, who was killed after a collision.': (0, 0, 8), 'Attempts to use machine learning in healthcare with the IBM Watson system failed to deliver even after years of time and billions of investment.': (0.8706610357857967, 1, 15), '=== Bias ===': (0, 0, 1), 'Machine learning approaches in particular can suffer from different data biases.': (0.8706610357857967, 1, 8), 'A machine learning system trained on current customers only may not be able to predict the needs of new customer groups that are not represented in the training data.': (0.8706610357857967, 1, 16), 'When trained on man-made data, machine learning is likely to pick up the same constitutional and unconscious biases already present in society.': (0.8706610357857967, 1, 13), 'Language models learned from data have been shown to contain human-like biases.': (0, 0, 8), 'Machine learning systems used for criminal risk assessment have been found to be biased against black people.': (0.8706610357857967, 1, 11), 'In 2015, Google photos would often tag black people as gorillas, and in 2018 this still was not well resolved, but Google reportedly was still using the workaround to remove all gorillas from the training data, and thus was not able to recognize real gorillas at all.': (0, 0, 25), 'Similar issues with recognizing non-white people have been found in many other systems.': (0, 0, 8), 'In 2016, Microsoft tested a chatbot that learned from Twitter, and it quickly picked up racist and sexist language.': (0, 0, 10), 'Because of such challenges, the effective use of machine learning may take longer to be adopted in other domains.': (0.8706610357857967, 1, 10), 'Concern for fairness in machine learning, that is, reducing bias in machine learning and propelling its use for human good is increasingly expressed by artificial intelligence scientists, including Fei-Fei Li, who reminds engineers that "There’s nothing artificial about AI...It’s inspired by people, it’s created by people, and—most importantly—it impacts people.': (1.7413220715715934, 2, 33), 'It is a powerful tool we are only just beginning to understand, and that is a profound responsibility.”': (0, 0, 6), '== Model assessments ==': (0, 0, 2), 'Classification machine learning models can be validated by accuracy estimation techniques like the Holdout method, which splits the data in a training and test set (conventionally 2/3 training set and 1/3 test set designation) and evaluates the performance of the training model on the test set.': (0.8706610357857967, 1, 28), 'In comparison, the K-fold-cross-validation method randomly partitions the data into K subsets and then K experiments are performed each respectively considering 1 subset for evaluation and the remaining K-1 subsets for training the model.': (0, 0, 20), 'In addition to the holdout and cross-validation methods, bootstrap, which samples n instances with replacement from the dataset, can be used to assess model accuracy.': (0, 0, 14), 'In addition to overall accuracy, investigators frequently report sensitivity and specificity meaning True Positive Rate (TPR) and True Negative Rate (TNR) respectively.': (0, 0, 18), 'Similarly, investigators sometimes report the False Positive Rate (FPR) as well as the False Negative Rate (FNR).': (0, 0, 13), 'However, these rates are ratios that fail to reveal their numerators and denominators.': (0, 0, 7), "The Total Operating Characteristic (TOC) is an effective method to express a model's diagnostic ability.": (0, 0, 10), "TOC shows the numerators and denominators of the previously mentioned rates, thus TOC provides more information than the commonly used Receiver Operating Characteristic (ROC) and ROC's associated Area Under the Curve (AUC).": (0, 0, 22), '== Ethics ==': (0, 0, 1), 'Machine learning poses a host of ethical questions.': (0.8706610357857967, 1, 6), 'Systems which are trained on datasets collected with biases may exhibit these biases upon use (algorithmic bias), thus digitizing cultural prejudices.': (0, 0, 16), 'For example, using job hiring data from a firm with racist hiring policies may lead to a machine learning system duplicating the bias by scoring job applicants against similarity to previous successful applicants.': (0.8706610357857967, 1, 23), 'Responsible collection of data and documentation of algorithmic rules used by a system thus is a critical part of machine learning.': (0.8706610357857967, 1, 13), 'Because human languages contain biases, machines trained on language corpora will necessarily also learn these biases.': (0, 0, 12), 'Other forms of ethical challenges, not related to personal biases, are more seen in health care.': (0, 0, 9), "There are concerns among health care professionals that these systems might not be designed in the public's interest but as income-generating machines.": (0, 0, 12), 'This is especially true in the United States where there is a long-standing ethical dilemma of improving health care, but also increasing profits.': (0, 0, 13), "For example, the algorithms could be designed to provide patients with unnecessary tests or medication in which the algorithm's proprietary owners hold stakes.": (0, 0, 14), 'There is huge potential for machine learning in health care to provide professionals a great tool to diagnose, medicate, and even plan recovery paths for patients, but this will not happen until the personal biases mentioned previously, and these "greed" biases are addressed.': (0.8706610357857967, 1, 25), '== Software ==': (0, 0, 1), 'Software suites containing a variety of machine learning algorithms include the following:': (0.8706610357857967, 1, 9), '=== Free and open-source software ===': (0, 0, 3), '=== Proprietary software with free and open-source editions ===': (0, 0, 5), '=== Proprietary software ===': (0, 0, 2), '== Journals ==': (0, 0, 1), 'Journal of Machine Learning Research': (0.8706610357857967, 1, 4), 'Machine Learning': (0.8706610357857967, 1, 2), 'Nature Machine Intelligence': (0, 0, 3), 'Neural Computation': (0, 0, 2), '== Conferences ==': (0, 0, 1), 'Conference on Neural Information Processing Systems': (0, 0, 5), 'International Conference on Machine Learning': (0.8706610357857967, 1, 4), '== See also ==': (0, 0, 2), '== References ==': (0, 0, 1), '== Further reading ==': (0, 0, 1), '== External links ==': (0, 0, 2), 'International Machine Learning Society': (0.8706610357857967, 1, 4), 'mloss is an academic database of open-source machine learning software.': (0.8706610357857967, 1, 7), 'Machine Learning Crash Course by Google.': (0.8706610357857967, 1, 5), 'This is a free course on machine learning through the use of TensorFlow.': (0.8706610357857967, 1, 6)}

# %%
from operator import itemgetter
sorted_sentence_idf = dict (sorted (dataset.items(), key=lambda row: (row[0], row[1]), reverse=True))

# %%
print (sorted_sentence_idf)
# Out:
# {'mloss is an academic database of open-source machine learning software.': (0.8706610357857967, 1, 7), 'is replaced with the question "Can machines do what we (as thinking entities) can do?': (0, 0, 5), 'https://en.wikipedia.org/wiki/Machine_learning': (0, 0, 2), 'Yet some practitioners, for example Dr Daniel Hulme, who both teaches AI and  runs a company operating in the field, argues that machine learning and AI are separate.': (0.8706610357857967, 1, 17), 'Work on symbolic/knowledge-based learning did continue within AI, leading to inductive logic programming, but the more statistical line of research was now outside the field of AI proper, in pattern recognition and information retrieval.': (0.8706610357857967, 1, 21), 'When trained on man-made data, machine learning is likely to pick up the same constitutional and unconscious biases already present in society.': (0.8706610357857967, 1, 13), 'When dealing with non-linear problems, go-to models include polynomial regression (for 
# ...

# %%
 data={'a':[12, 'tall', 'blue', 1],'b':[2, 'short', 'red', 9],'c':[4, 'tall', 'blue', 13],'d':[12, 'tall', 'blue', 13]}

 result = sorted(data.items(), key = lambda x: (x[1][0], x[1][3]), reverse=True)
 print(result)
# Out:
# [('d', [12, 'tall', 'blue', 13]), ('a', [12, 'tall', 'blue', 1]), ('c', [4, 'tall', 'blue', 13]), ('b', [2, 'short', 'red', 9])]

# %%
$ python questions.py corpus
Query: What are the types of supervised learning?
Types of supervised learning algorithms include Active learning , classification and regression.

$ python questions.py corpus
Query: When was Python 3.0 released?
Python 3.0 was released on 3 December 2008.

$ python questions.py corpus
Query: How do neurons connect in a neural network?
Neurons of one layer connect only to neurons of the immediately preceding and immediately following layers.
